# %% [markdown]
# # Read .bdf files and convert to .h5
# For import to MATLAB and Python
# Script performs the following:
# - Read .bdf file
# - Select only EEG channels/discard EOG, EMG
# - Reference to the common average
# - Filter DC offset and 50hz notch
# - Clip off the noisy end of data
# - Export to .h5

# %%
import os
import numpy as np
import mne
import pathlib
import matplotlib.pyplot as plt

# %%
path=pathlib.Path('/media/tris/tris_files/DEAP_dataset/data_original')
path
# Out:
# PosixPath('/media/tris/tris_files/DEAP_dataset/data_original')

# %%
raw=mne.io.read_raw_bdf(path/'s04.bdf')
raw.load_data()
# Out:
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s04.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1690111  =      0.000 ...  3300.998 secs...
# <RawEDF | s04.bdf, 48 x 1690112 (3301.0 s), ~619.0 MB, data loaded>

# %%
eeg_channels=raw.ch_names[0:32] #first 32 channels are the EEG ones
eeg_channels
# Out:
# ['Fp1',
#  'AF3',
#  'F7',
#  'F3',
#  'FC1',
#  'FC5',
#  'T7',
#  'C3',
#  'CP1',
#  'CP5',
#  'P7',
#  'P3',
#  'Pz',
#  'PO3',
#  'O1',
#  'Oz',
#  'O2',
#  'PO4',
#  'P4',
#  'P8',
#  'CP6',
#  'CP2',
#  'C4',
#  'T8',
#  'FC6',
#  'FC2',
#  'F4',
#  'F8',
#  'AF4',
#  'Fp2',
#  'Fz',
#  'Cz']

# %%
eog_channels=raw.ch_names[32:36];eog_channels
# Out:
# ['EXG1', 'EXG2', 'EXG3', 'EXG4']

# %%
emg_channels=raw.ch_names[36:40];emg_channels
# Out:
# ['EXG5', 'EXG6', 'EXG7', 'EXG8']

# %%
raw.pick_channels(eeg_channels) #select only the EEG channels
# Out:
# <RawEDF | s04.bdf, 32 x 1690112 (3301.0 s), ~412.7 MB, data loaded>

# %%
raw.plot()

# %%
raw.set_eeg_reference(ref_channels=['Cz']) #reference to the Cz node, common for biosig
# Out:
# EEG channel type selected for re-referencing
# Applying a custom EEG reference.
# <RawEDF | s04.bdf, 32 x 1690112 (3301.0 s), ~412.7 MB, data loaded>

# %%
raw.plot()

# %%
raw_avg=raw.copy().set_eeg_reference(ref_channels='average') #reference to the average (I think is more stable)
raw_avg.plot()
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.

# %%
fig = raw_avg.plot_psd(tmax=np.inf, fmax=250, average=True) #check orginal PSD
# Out:
# Effective window size : 4.000 (s)

# %%
ssp_projectors = raw.info['projs']
raw.del_proj()
# Out:
# <RawEDF | s04.bdf, 32 x 1690112 (3301.0 s), ~412.7 MB, data loaded>

# %%
raw_avg.notch_filter(49.5,picks=eeg_channels)
raw_avg.notch_filter(50,picks=eeg_channels)
raw_avg.notch_filter(50.5,picks=eeg_channels)
raw_avg.notch_filter(150,picks=eeg_channels)
raw_avg.filter(0.5,None, fir_design='firwin')
# Out:
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
# <RawEDF | s04.bdf, 32 x 1690112 (3301.0 s), ~412.7 MB, data loaded>

# %%
fig = raw_avg.plot_psd(tmax=np.inf, fmax=250, average=True) #check orginal PSD
# Out:
# Effective window size : 4.000 (s)

# %%
avg_psd=raw_avg.plot_psd(average=True)
# Out:
# Effective window size : 4.000 (s)

# %%
raw_avg_downsampled = raw_avg.copy().resample(sfreq=256) #check downsample PSD
fig=raw_avg_downsampled.plot_psd(average=True)
# Out:
# Effective window size : 8.000 (s)

# %%
raw_avg_downsampled2 = raw_avg.copy().resample(sfreq=128) #check downsample PSD
avg_psd_128=raw_avg_downsampled.plot_psd(average=True)
# Out:
# Effective window size : 8.000 (s)

# %%
df=raw_avg.to_data_frame(scalings=1e6) #convert to pandas
df.head()
# Out:
#    time           Fp1           AF3            F7            F3           FC1  \
# 0     0  9.012431e-13 -3.316981e-12 -8.080694e-13  7.487771e-13 -4.506215e-13
# 1     2 -1.241470e+00 -5.474095e+00  4.477490e+00  2.736919e+00 -1.048958e-01
# 2     4 -4.609153e+00 -3.498343e+00  6.900541e+00  4.551631e+00  4.188673e-01
# 3     6 -1.166402e+01  5.178599e-01  5.017465e+00  3.975985e+00  2.460036e-01
# 4     8 -2.014372e+01  2.738439e+00  2.983371e+00  3.412385e+00  8.589798e-01
#
#             FC5            T7            C3           CP1  ...            C4  \
# 0  1.532283e-12 -1.882954e-12 -3.388132e-14  1.551764e-12  ...  5.361719e-13
# 1  5.943661e+00  6.402947e+00  2.053409e+00  9.927584e-02  ... -1.310441e+00
# 2  7.659318e+00  8.288965e+00  3.082638e+00  1.065397e+00  ... -3.039131e+00
# 3  6.401387e+00  9.027895e+00  2.800221e+00  2.355350e-01  ... -2.643637e+00
# 4  6.621415e+00  9.692553e+00  2.505618e+00 -9.290968e-01  ... -1.480617e+00
#
#              T8           FC6           FC2            F4            F8  \
# 0  6.945670e-14 -8.690558e-13  2.625802e-14 -3.123858e-12 -4.294457e-13
# 1  5.043919e-01 -2.096406e+00 -9.663914e-01 -1.313761e+00 -3.087859e+00
# 2 -3.703856e+00 -2.317287e+00 -1.036220e+00 -7.914592e-01 -2.277755e+00
# 3 -5.843972e+00 -1.302269e+00 -1.882443e+00 -2.668658e+00 -1.387082e+00
# 4 -1.294322e+00  4.358487e-01 -2.304981e+00 -3.358448e+00 -1.028475e+00
#
#             AF4           Fp2            Fz            Cz
# 0 -2.862971e-12  2.434373e-12  1.694066e-13 -1.583952e-13
# 1 -4.896316e+00 -5.655722e+00  4.490750e-01 -1.140034e+00
# 2 -5.798047e+00 -9.278250e+00  5.399186e-01 -1.631666e+00
# 3 -6.064028e+00 -1.222537e+01 -9.712418e-01 -1.566306e+00
# 4 -4.532304e+00 -1.237950e+01 -1.602166e+00 -1.243047e+00
#
# [5 rows x 33 columns]

# %%
fs=512
stop_time=len(df)/(fs*60)

# %%
df['time']=np.linspace(0,stop_time,num=len(df))

# %%
df.head()
# Out:
#        time           Fp1           AF3        F7            F3           FC1  \
# 0  0.000000 -6.776264e-15 -8.470329e-15  0.000000 -1.694066e-15  4.870439e-15
# 1  0.000033 -5.960176e-01 -6.870556e+00  3.314295  2.045063e+00 -3.398310e-01
# 2  0.000065 -3.556770e+00 -5.751907e+00  5.055018  3.497772e+00  9.464854e-02
# 0        5.505714e-15 -2.541099e-15  3.811648e-15  1.694066e-15  8.470329e-16
# 1       -1.342191e+00 -3.196025e+00 -4.956818e+00 -5.327699e+00  1.999763e-01
# 2       -8.162345e-01 -2.451618e+00 -5.849859e+00 -8.701367e+00  1.664011e-01
# 3       -2.688035e+00 -1.574378e+00 -6.100977e+00 -1.158781e+01 -1.347061e+00
# 4       -3.376323e+00 -1.182424e+00 -4.553094e+00 -1.187328e+01 -1.862451e+00
# ...               ...           ...           ...           ...           ...
# 1690107  6.509510e+00 -3.622766e+00 -7.096285e+00  2.876275e+01  4.043425e+00
# 1690108  6.838611e+00 -2.535395e+00  7.744142e-01  2.373668e+01  3.475113e+00
# 1690109  4.832036e+00 -2.418670e-01  1.981675e+00  1.394428e+01  2.837098e+00
# 1690110  1.467963e+00 -5.111556e-01  2.598126e-01  1.744962e+00  1.366524e+00
# 1690111  3.388132e-15  6.776264e-15  6.776264e-15  6.776264e-15 -1.694066e-15
#
#                    Cz
# 0        3.388132e-15
# 1       -1.055092e+00
# 2       -1.459934e+00
# 3       -1.386293e+00
# 4       -1.144016e+00
# ...               ...
# 1690107  3.267938e+00
# 1690108  2.949748e+00
# 1690109  1.317297e+00
# 1690110  4.548879e-02
# 1690111 -6.776264e-15
#
# [1690112 rows x 33 columns]

# %%
df.to_hdf('s05.h5',key='df')

# %%
np.arange(48,49,50,51,52)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-8d6a81a8e10d> in <module>
# ----> 1 np.arange(48,49,50,51,52)
#
# TypeError: arange() takes at most 4 arguments (5 given)

# %%
path = '/media/tris/tris_files/DEAP_dataset/data_original/s01.bdf'
raw=mne.io.read_raw_bdf(path)
raw.load_data()
eeg_channels=raw.ch_names[0:32]
raw.pick_channels(eeg_channels) #select only the EEG channels
raw_avg=raw.copy().set_eeg_reference(ref_channels='average')
raw_avg.notch_filter(49.5,picks=eeg_channels)
raw_avg.notch_filter(50,picks=eeg_channels)
raw_avg.notch_filter(50.5,picks=eeg_channels)
raw_avg.notch_filter(150,picks=eeg_channels)
raw_avg.filter(0.5,None, fir_design='firwin')
raw_avg_500 = raw_avg.copy().resample(sfreq=500)
raw_avg_240 = raw_avg.copy().resample(sfreq=240)
raw_avg_120 = raw_avg.copy().resample(sfreq=120)
raw_avg_256 = raw_avg.copy().resample(sfreq=256)
raw_avg_128 = raw_avg.copy().resample(sfreq=128)
df_512=raw_avg.to_data_frame(scalings=1e6)
df_500=raw_avg_500.to_data_frame(scalings=1e6)
df_240=raw_avg_240.to_data_frame(scalings=1e6)
df_120=raw_avg_120.to_data_frame(scalings=1e6)
df_256=raw_avg_256.to_data_frame(scalings=1e6)
df_128=raw_avg_128.to_data_frame(scalings=1e6)
df_512=df_512.iloc[0:60*60*512][:]
df_256=df_256.iloc[0:60*60*256][:]
df_128=df_128.iloc[0:60*60*128][:]
df_500=df_500.iloc[0:60*60*500][:]
df_240=df_240.iloc[0:60*60*240][:]
df_120=df_120.iloc[0:60*60*120][:]
df_512.to_hdf('s01_512.h5',key='df_512')
df_256.to_hdf('s01_256.h5',key='df_256')
df_128.to_hdf('s01_128.h5',key='df_128')
df_500.to_hdf('s01_500.h5',key='df_500')
df_240.to_hdf('s01_240.h5',key='df_240')
df_120.to_hdf('s01_120.h5',key='df_120')
# Out:
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s01.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1980927  =      0.000 ...  3868.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)

# %%
for n in range (2,10):
    path = '/media/tris/tris_files/DEAP_dataset/data_original/s0'+str(n)+'.bdf'
    raw=mne.io.read_raw_bdf(path)
    raw.load_data()
    eeg_channels=raw.ch_names[0:32]
    raw.pick_channels(eeg_channels) #select only the EEG channels
    raw_avg=raw.copy().set_eeg_reference(ref_channels='average')
    raw_avg.notch_filter(49.5,picks=eeg_channels)
    raw_avg.notch_filter(50,picks=eeg_channels)
    raw_avg.notch_filter(50.5,picks=eeg_channels)
    raw_avg.notch_filter(150,picks=eeg_channels)
    raw_avg.filter(0.5,None, fir_design='firwin')
    raw_avg_256 = raw_avg.copy().resample(sfreq=256)
    raw_avg_128 = raw_avg.copy().resample(sfreq=128)
    raw_avg_240 = raw_avg.copy().resample(sfreq=240)
    raw_avg_120 = raw_avg.copy().resample(sfreq=120)
    raw_avg_500 = raw_avg.copy().resample(sfreq=500)
    df_512=raw_avg.to_data_frame(scalings=1e6)
    df_256=raw_avg_256.to_data_frame(scalings=1e6)
    df_128=raw_avg_128.to_data_frame(scalings=1e6)
    df_500=raw_avg_500.to_data_frame(scalings=1e6)
    df_240=raw_avg_240.to_data_frame(scalings=1e6)
    df_120=raw_avg_120.to_data_frame(scalings=1e6)
    df_512=df_512.iloc[0:60*60*512][:]
    df_256=df_256.iloc[0:60*60*256][:]
    df_128=df_128.iloc[0:60*60*128][:]
    df_500=df_500.iloc[0:60*60*500][:]
    df_240=df_240.iloc[0:60*60*240][:]
    df_120=df_120.iloc[0:60*60*120][:]
    df_512.to_hdf('s0'+str(n)+'_512.h5',key='df_512')
    df_256.to_hdf('s0'+str(n)+'_256.h5',key='df_256')
    df_128.to_hdf('s0'+str(n)+'_128.h5',key='df_128')
    df_500.to_hdf('s0'+str(n)+'_500.h5',key='df_500')
    df_240.to_hdf('s0'+str(n)+'_240.h5',key='df_240')
    df_120.to_hdf('s0'+str(n)+'_120.h5',key='df_120')
for n in range (10,33):
    path = '/media/tris/tris_files/DEAP_dataset/data_original/s'+str(n)+'.bdf'
    raw=mne.io.read_raw_bdf(path)
    raw.load_data()
    eeg_channels=raw.ch_names[0:32]
    raw.pick_channels(eeg_channels) #select only the EEG channels
    raw_avg=raw.copy().set_eeg_reference(ref_channels='average')
    raw_avg.notch_filter(49.5,picks=eeg_channels)
    raw_avg.notch_filter(50,picks=eeg_channels)
    raw_avg.notch_filter(50.5,picks=eeg_channels)
    raw_avg.notch_filter(150,picks=eeg_channels)
    raw_avg.filter(0.5,None, fir_design='firwin')
    raw_avg_256 = raw_avg.copy().resample(sfreq=256)
    raw_avg_128 = raw_avg.copy().resample(sfreq=128)
    raw_avg_240 = raw_avg.copy().resample(sfreq=240)
    raw_avg_120 = raw_avg.copy().resample(sfreq=120)
    raw_avg_500 = raw_avg.copy().resample(sfreq=500)
    df_512=raw_avg.to_data_frame(scalings=1e6)
    df_256=raw_avg_256.to_data_frame(scalings=1e6)
    df_128=raw_avg_128.to_data_frame(scalings=1e6)
    df_500=raw_avg_500.to_data_frame(scalings=1e6)
    df_240=raw_avg_240.to_data_frame(scalings=1e6)
    df_120=raw_avg_120.to_data_frame(scalings=1e6)
    df_512=df_512.iloc[0:60*60*512][:]
    df_256=df_256.iloc[0:60*60*256][:]
    df_128=df_128.iloc[0:60*60*128][:]
    df_500=df_500.iloc[0:60*60*500][:]
    df_240=df_240.iloc[0:60*60*240][:]
    df_120=df_120.iloc[0:60*60*120][:]
    df_512.to_hdf('s'+str(n)+'_512.h5',key='df_512')
    df_256.to_hdf('s'+str(n)+'_256.h5',key='df_256')
    df_128.to_hdf('s'+str(n)+'_128.h5',key='df_128')
    df_500.to_hdf('s'+str(n)+'_500.h5',key='df_500')
    df_240.to_hdf('s'+str(n)+'_240.h5',key='df_240')
    df_120.to_hdf('s'+str(n)+'_120.h5',key='df_120')
# Out:
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s02.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1895935  =      0.000 ...  3702.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s03.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1989119  =      0.000 ...  3884.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s04.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1690111  =      0.000 ...  3300.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s05.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2004991  =      0.000 ...  3915.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s06.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1836031  =      0.000 ...  3585.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s07.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1828351  =      0.000 ...  3570.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s08.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1800703  =      0.000 ...  3516.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s09.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1928703  =      0.000 ...  3766.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s10.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1798143  =      0.000 ...  3511.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s11.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2130431  =      0.000 ...  4160.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s12.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1790975  =      0.000 ...  3497.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s13.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1900031  =      0.000 ...  3710.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s14.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2015743  =      0.000 ...  3936.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s15.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2084863  =      0.000 ...  4071.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s16.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1885695  =      0.000 ...  3682.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s17.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1764351  =      0.000 ...  3445.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s18.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1857535  =      0.000 ...  3627.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# ...
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s28.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1805823  =      0.000 ...  3526.998 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s29.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 2036735  =      0.000 ...  3977.998 secs...
# <ipython-input-35-bf45d7cbd387>:38: RuntimeWarning: Channel names are not unique, found duplicates for: {''}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_bdf(path)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s30.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1876479  =      0.000 ...  3664.998 secs...
# <ipython-input-35-bf45d7cbd387>:38: RuntimeWarning: Channel names are not unique, found duplicates for: {''}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_bdf(path)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s31.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1892351  =      0.000 ...  3695.998 secs...
# <ipython-input-35-bf45d7cbd387>:38: RuntimeWarning: Channel names are not unique, found duplicates for: {''}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_bdf(path)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Extracting EDF parameters from /media/tris/tris_files/DEAP_dataset/data_original/s32.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1804287  =      0.000 ...  3523.998 secs...
# <ipython-input-35-bf45d7cbd387>:38: RuntimeWarning: Channel names are not unique, found duplicates for: {''}. Applying running numbers for duplicates.
#   raw=mne.io.read_raw_bdf(path)
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom EEG reference.
# Setting up band-stop filter from 49 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 48.88
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 48.63 Hz)
# - Upper passband edge: 50.12 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.37 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 49 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.38
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.12 Hz)
# - Upper passband edge: 50.62 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 50.88 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 50 - 51 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 49.87
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 49.62 Hz)
# - Upper passband edge: 51.13 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 51.38 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Setting up band-stop filter from 1.5e+02 - 1.5e+02 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 149.12
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 148.88 Hz)
# - Upper passband edge: 150.88 Hz
# - Upper transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 151.12 Hz)
# - Filter length: 3379 samples (6.600 sec)
#
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 0.5 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Filter length: 3379 samples (6.600 sec)
