# %% [markdown]
# # Tabular ANN for Exploration of DEAP Dataset
# Fingerprinting with DMD modes has worked really well. What about in tabular format?
#
# Predict Trial

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
# %%javascript
# utils.load_extension('collapsible_headings/main')
# utils.load_extension('hide_input/main')
# utils.load_extension('execute_time/ExecuteTime')
# utils.load_extension('code_prettify/code_prettify')
# utils.load_extension('scroll_down/main')
# utils.load_extension('jupyter-js-widgets/extension')

# %%
from fastai.tabular import *
from sklearn import preprocessing

# %%
PATH = "/media/tris/tris_files/EEG_datasets/DMD/tabular"

# %%
df_raw = pd.read_csv('/media/tris/tris_files/EEG_datasets/DMD/tabular/dmd_deap_50modes_trials3.csv')
df_raw
# Out:
#       Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 0           1      1          0.614814         -0.087397         -0.320053
# 1           1      2         -0.088526          0.975644         -0.866643
# 2           1      3          0.482252         -1.007487          0.036876
# 3           1      4          0.823915          0.041140          0.927601
# 4           1      5         -0.774046          0.262418         -0.461349
# ...       ...    ...               ...               ...               ...
# 1275       32     36         -3.320858          0.570013         -0.319125
# 1276       32     37         -0.874191         -3.777669         -2.503243
# 1277       32     38          0.632914         -0.966359          3.129836
# 1278       32     39         -2.764089         -3.496597         -1.853411
# 1279       32     40          4.300082          0.274255          1.548403
#
#       Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 0             1.410603         -0.789681         -0.030823          0.326317
# 1             1.589470          0.014409          0.428341          1.857337
# 2             0.447674          0.272007          2.752983          0.763709
# 3            -0.803980         -0.500776         -1.271204         -0.772469
# 4             2.512446         -0.139493         -0.129015          1.446123
# ...                ...               ...               ...               ...
# 1275         -0.852716         -3.327261          1.185592          0.295865
# 1276         -0.574673          1.832012         -1.139289         -2.304741
# 1277          1.385485          0.085605          0.799532         -2.165469
# 1278          0.263244          1.120005          2.785592         -0.091470
# 1279         -0.059285          4.322519         -2.555328          0.106013
#
#       Real_Comp8_Mode1  ...    zeta16    zeta17    zeta18    zeta19    zeta20  \
# 0            -0.286574  ...  0.493882  0.147711  0.056847  0.142136  0.105085
# 1             0.037218  ...  0.977107  0.052504  0.141810  0.081457  0.163943
# 2            -1.409766  ...  0.881263  0.071147  0.049642  0.155528  0.132861
# 3            -0.603872  ...  0.060358  0.108309  0.157512  0.061951  0.210791
# 4             0.252169  ...  0.053968  0.123062  0.079270  0.145170  0.075568
# ...                ...  ...       ...       ...       ...       ...       ...
# 1275         -0.362428  ...  1.000000  0.995469  0.076210  0.104502  0.234229
# 1276         -0.698633  ...  1.000000  0.096682  0.072892  0.255940  0.134141
# 1277          0.573599  ...  0.879621  0.061895  0.921325  0.126629  0.101454
# 1278         -1.250502  ...  1.000000  0.544934  0.077994  0.127893  0.123439
# 1279          0.526317  ...  1.000000  1.000000  0.073954  0.233740  0.121029
#
#         zeta21    zeta22    zeta23    zeta24    zeta25
# 0     0.144424  0.175822  0.132348  0.157219  0.219461
# 1     0.163877  0.149706  0.204827  0.162412  0.140685
# 2     0.180283  0.135714  0.187156  0.113682  0.184400
# 3     0.137637  0.207966  0.096923  0.152389  0.149941
# 4     0.219668  0.176209  0.195444  0.116692  0.173520
# ...        ...       ...       ...       ...       ...
# 1275  0.145891  0.166352  0.198434  0.168770  0.179259
# 1276  0.120458  0.180773  0.155041  0.193442  0.164560
# 1277  0.173624  0.146204  0.190822  0.207933  0.217672
# 1278  0.079106  0.191528  0.153139  0.164365  0.354397
# 1279  0.169874  0.186341  0.175731  0.130541  0.155160
#
# [1280 rows x 602 columns]

# %%
df_raw.iloc[[40],:]
# Out:
#     Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 40        2      1          0.893205          0.294573          1.122256
#
#     Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 40         -0.653728         -1.370544          0.135854         -0.107045
#
#     Real_Comp8_Mode1  ...  zeta16    zeta17    zeta18    zeta19    zeta20  \
# 40          0.099121  ...     1.0  0.877191  0.099661  0.131439  0.193674
#
#       zeta21    zeta22    zeta23    zeta24    zeta25
# 40  0.043877  0.151126  0.129442  0.116061  0.232432
#
# [1 rows x 602 columns]

# %%
os.makedirs('tmp', exist_ok=True)
df_raw.to_feather('tmp/eeg-raw')

# %%
import pandas as pd
df_raw = pd.read_feather('tmp/eeg-raw') #lol raw sashimis and sushis
df_raw.head()
# Out:
#    Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 0        1      1          0.614814         -0.087397         -0.320053
# 1        1      2         -0.088526          0.975644         -0.866643
# 2        1      3          0.482252         -1.007487          0.036876
# 3        1      4          0.823915          0.041140          0.927601
# 4        1      5         -0.774046          0.262418         -0.461349
#
#    Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 0          1.410603         -0.789681         -0.030823          0.326317
# 1          1.589470          0.014409          0.428341          1.857337
# 2          0.447674          0.272007          2.752983          0.763709
# 3         -0.803980         -0.500776         -1.271204         -0.772469
# 4          2.512446         -0.139493         -0.129015          1.446123
#
#    Real_Comp8_Mode1  ...    zeta16    zeta17    zeta18    zeta19    zeta20  \
# 0         -0.286574  ...  0.493882  0.147711  0.056847  0.142136  0.105085
# 1          0.037218  ...  0.977107  0.052504  0.141810  0.081457  0.163943
# 2         -1.409766  ...  0.881263  0.071147  0.049642  0.155528  0.132861
# 3         -0.603872  ...  0.060358  0.108309  0.157512  0.061951  0.210791
# 4          0.252169  ...  0.053968  0.123062  0.079270  0.145170  0.075568
#
#      zeta21    zeta22    zeta23    zeta24    zeta25
# 0  0.144424  0.175822  0.132348  0.157219  0.219461
# 1  0.163877  0.149706  0.204827  0.162412  0.140685
# 2  0.180283  0.135714  0.187156  0.113682  0.184400
# 3  0.137637  0.207966  0.096923  0.152389  0.149941
# 4  0.219668  0.176209  0.195444  0.116692  0.173520
#
# [5 rows x 602 columns]

# %%
df_raw.iloc[[500],:]
# Out:
#      Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 500       13     21           1.21969          1.206651          -2.34162
#
#      Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 500          -1.14813         -0.154275          1.589916          1.227194
#
#      Real_Comp8_Mode1  ...    zeta16  zeta17    zeta18    zeta19   zeta20  \
# 500         -0.450896  ...  0.119874     1.0  0.478022  0.150209  0.34918
#
#        zeta21    zeta22    zeta23    zeta24    zeta25
# 500  0.161538  0.128439  0.123845  0.196405  0.267015
#
# [1 rows x 602 columns]

# %%
path = '/media/tris/tris_files/EEG_datasets/DEAP_data_preprocessed_python/s01.dat'
df_read = pickle.load(open(path, 'rb'), encoding='latin1')
labels=df_read['labels']
df_tmp = pd.DataFrame(labels, columns=['valence','arousal','dominance','liking'])
df=df_tmp
for n in range (2,10):
    path = '/media/tris/tris_files/EEG_datasets/DEAP_data_preprocessed_python/s0'+str(n)+'.dat'
    df_read = pickle.load(open(path, 'rb'), encoding='latin1')
    labels=df_read['labels']
    df_tmp = pd.DataFrame(labels, columns=['valence','arousal','dominance','liking'])
    df=df.append(df_tmp, ignore_index=True)
for n in range (10,33):
    path = '/media/tris/tris_files/EEG_datasets/DEAP_data_preprocessed_python/s'+str(n)+'.dat'
    df_read = pickle.load(open(path, 'rb'), encoding='latin1')
    labels=df_read['labels']
    df_tmp = pd.DataFrame(labels, columns=['valence','arousal','dominance','liking'])
    df=df.append(df_tmp, ignore_index=True)

# %%
df=df.div(9) #normalize
# valence = df[['valence']].values.astype(float)
# arousal = df[['arousal']].values.astype(float)
# min_max_scaler = preprocessing.MinMaxScaler()
# v_scaled = min_max_scaler.fit_transform(valence)
# a_scaled = min_max_scaler.fit_transform(arousal)
# v_scaled = preprocessing.scale(v_scaled)
# a_scaled = preprocessing.scale(a_scaled)
# v_normalized = pd.DataFrame(v_scaled, columns=['v_scale'])
# a_normalized = pd.DataFrame(a_scaled, columns=['a_scale'])
# df_norm=pd.concat([df[['valence']],v_normalized,a_normalized], axis=1)
# df_norm.head()

# %%
df.loc[(df['valence'] >= 0.5) & (df['arousal'] >= 0.5), 'emotion_quad'] = 'HVHA'
df.loc[(df['valence'] <= 0.5) & (df['arousal'] >= 0.5), 'emotion_quad'] = 'LVHA'
df.loc[(df['valence'] <= 0.5) & (df['arousal'] <= 0.5), 'emotion_quad'] = 'LVLA'  
df.loc[(df['valence'] >= 0.5) & (df['arousal'] <= 0.5), 'emotion_quad'] = 'HVLA'
df.tail()
# Out:
#        valence   arousal  dominance    liking emotion_quad
# 1275  0.434444  0.773333   0.646667  0.346667         LVHA
# 1276  0.312222  0.681111   0.673333  0.115556         LVHA
# 1277  0.338889  0.778889   0.566667  0.122222         LVHA
# 1278  0.443333  0.796667   0.538889  0.111111         LVHA
# 1279  0.794444  0.447778   1.000000  0.208889         HVLA

# %%
emotion_quad = df['emotion_quad']
df_learn = df_raw.join(emotion_quad)
df_learn.head()
# Out:
#    Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 0        1      1          0.614814         -0.087397         -0.320053
# 1        1      2         -0.088526          0.975644         -0.866643
# 2        1      3          0.482252         -1.007487          0.036876
# 3        1      4          0.823915          0.041140          0.927601
# 4        1      5         -0.774046          0.262418         -0.461349
#
#    Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 0          1.410603         -0.789681         -0.030823          0.326317
# 1          1.589470          0.014409          0.428341          1.857337
# 2          0.447674          0.272007          2.752983          0.763709
# 3         -0.803980         -0.500776         -1.271204         -0.772469
# 4          2.512446         -0.139493         -0.129015          1.446123
#
#    Real_Comp8_Mode1  ...    zeta17    zeta18    zeta19    zeta20    zeta21  \
# 0         -0.286574  ...  0.147711  0.056847  0.142136  0.105085  0.144424
# 1          0.037218  ...  0.052504  0.141810  0.081457  0.163943  0.163877
# 2         -1.409766  ...  0.071147  0.049642  0.155528  0.132861  0.180283
# 3         -0.603872  ...  0.108309  0.157512  0.061951  0.210791  0.137637
# 4          0.252169  ...  0.123062  0.079270  0.145170  0.075568  0.219668
#
#      zeta22    zeta23    zeta24    zeta25  emotion_quad
# 0  0.175822  0.132348  0.157219  0.219461          HVHA
# 1  0.149706  0.204827  0.162412  0.140685          HVHA
# 2  0.135714  0.187156  0.113682  0.184400          HVHA
# 3  0.207966  0.096923  0.152389  0.149941          HVHA
# 4  0.176209  0.195444  0.116692  0.173520          HVLA
#
# [5 rows x 603 columns]

# %%
fig, axs = plt.subplots(1, 5, figsize=(15, 5))
axs[0].hist(df_learn.Real_Comp1_Mode1)
axs[0].set_title('Real_Comp1_Mode1')
axs[1].hist(df_learn.fn3)
axs[1].set_title('fn3')
axs[2].hist(df_learn.Imag_Comp1_Mode1)
axs[2].set_title('Imag_Comp1_Mode1')
axs[3].hist(df_learn.zeta10)
axs[3].set_title('zeta10')
axs[4].hist(df_learn.emotion_quad)
axs[4].set_title('label')
# Out:
# Text(0.5, 1.0, 'label')

# %%
valid_idx=np.random.randint(low=0, high=len(df_learn), size=256)

# %%
dep_var= 'Trial'

# %%
path = "/media/tris/tris_files/EEG_datasets/DMD/tabular"
procs = [Categorify, FillMissing, Normalize]

# %%
data = TabularDataBunch.from_df(path, df_learn, dep_var, valid_idx=valid_idx, cat_names=['emotion_quad'], procs=procs,)

# %%
data.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>emotion_quad</th>
#       <th>Real_Comp10_Mode10</th>
#       <th>Imag_Comp4_Mode13</th>
#       <th>Imag_Comp2_Mode13</th>
#       <th>Imag_Comp6_Mode20</th>
#       <th>Real_Comp7_Mode11</th>
#       <th>Real_Comp1_Mode17</th>
#       <th>Imag_Comp1_Mode23</th>
#       <th>Real_Comp4_Mode9</th>
#       <th>Imag_Comp11_Mode5</th>
#       <th>Imag_Comp7_Mode6</th>
#       <th>Imag_Comp5_Mode16</th>
#       <th>Real_Comp3_Mode1</th>
#       <th>Real_Comp9_Mode7</th>
#       <th>Real_Comp9_Mode5</th>
#       <th>Imag_Comp7_Mode9</th>
#       <th>Imag_Comp2_Mode6</th>
#       <th>Real_Comp11_Mode25</th>
#       <th>Real_Comp1_Mode8</th>
#       <th>Imag_Comp7_Mode19</th>
#       <th>Imag_Comp4_Mode23</th>
#       <th>Imag_Comp9_Mode7</th>
#       <th>Imag_Comp5_Mode10</th>
#       <th>Real_Comp9_Mode1</th>
#       <th>Real_Comp8_Mode19</th>
#       <th>Real_Comp6_Mode22</th>
#       <th>Real_Comp11_Mode4</th>
#       <th>Real_Comp3_Mode9</th>
#       <th>Real_Comp11_Mode9</th>
#       <th>Real_Comp10_Mode7</th>
#       <th>Real_Comp8_Mode18</th>
#       <th>Imag_Comp2_Mode23</th>
#       <th>Imag_Comp11_Mode3</th>
#       <th>Imag_Comp9_Mode11</th>
#       <th>Real_Comp3_Mode23</th>
#       <th>Imag_Comp9_Mode4</th>
#       <th>Imag_Comp2_Mode17</th>
#       <th>Imag_Comp2_Mode24</th>
#       <th>Real_Comp4_Mode22</th>
#       <th>Imag_Comp6_Mode17</th>
#       <th>Real_Comp10_Mode16</th>
#       <th>Imag_Comp5_Mode22</th>
#       <th>Imag_Comp10_Mode9</th>
#       <th>fn20</th>
#       <th>fn13</th>
#       <th>Real_Comp3_Mode5</th>
#       <th>Imag_Comp11_Mode17</th>
#       <th>Real_Comp5_Mode9</th>
#       <th>Imag_Comp6_Mode10</th>
#       <th>Imag_Comp4_Mode11</th>
#       <th>Imag_Comp3_Mode11</th>
#       <th>Imag_Comp7_Mode7</th>
#       <th>Imag_Comp3_Mode22</th>
#       <th>Imag_Comp6_Mode9</th>
#       <th>Real_Comp5_Mode14</th>
#       <th>Imag_Comp11_Mode6</th>
#       <th>Real_Comp4_Mode4</th>
#       <th>zeta11</th>
#       <th>Real_Comp3_Mode8</th>
#       <th>Imag_Comp11_Mode4</th>
#       <th>Imag_Comp4_Mode8</th>
#       <th>Imag_Comp9_Mode23</th>
#       <th>Real_Comp8_Mode5</th>
#       <th>Imag_Comp3_Mode10</th>
#       <th>Real_Comp8_Mode1</th>
#       <th>Imag_Comp1_Mode1</th>
#       <th>fn5</th>
#       <th>Real_Comp4_Mode6</th>
#       <th>Real_Comp2_Mode19</th>
#       <th>Imag_Comp9_Mode18</th>
#       <th>zeta21</th>
#       <th>Real_Comp9_Mode19</th>
#       <th>Real_Comp9_Mode13</th>
#       <th>Imag_Comp5_Mode24</th>
#       <th>zeta10</th>
#       <th>Imag_Comp4_Mode5</th>
#       <th>Imag_Comp3_Mode24</th>
#       <th>Imag_Comp11_Mode15</th>
#       <th>Imag_Comp4_Mode16</th>
#       <th>Real_Comp3_Mode2</th>
#       <th>zeta7</th>
#       <th>fn16</th>
#       <th>Imag_Comp8_Mode7</th>
#       <th>Imag_Comp10_Mode11</th>
#       <th>Real_Comp6_Mode16</th>
#       <th>Real_Comp11_Mode3</th>
#       <th>Real_Comp7_Mode16</th>
#       <th>Real_Comp11_Mode16</th>
#       <th>Imag_Comp11_Mode7</th>
#       <th>Imag_Comp3_Mode13</th>
#       <th>Real_Comp8_Mode11</th>
#       <th>Imag_Comp1_Mode15</th>
#       <th>Real_Comp7_Mode19</th>
#       <th>Imag_Comp2_Mode20</th>
#       <th>Real_Comp5_Mode3</th>
#       <th>Real_Comp5_Mode11</th>
#       <th>Real_Comp7_Mode22</th>
#       <th>Real_Comp5_Mode25</th>
#       <th>Imag_Comp6_Mode24</th>
#       <th>Real_Comp4_Mode8</th>
#       <th>Imag_Comp8_Mode22</th>
#       <th>Real_Comp8_Mode6</th>
#       <th>Imag_Comp10_Mode3</th>
#       <th>Real_Comp9_Mode25</th>
#       <th>Imag_Comp5_Mode12</th>
#       <th>Real_Comp2_Mode24</th>
#       <th>Imag_Comp10_Mode23</th>
#       <th>Imag_Comp11_Mode13</th>
#       <th>Imag_Comp2_Mode14</th>
#       <th>Real_Comp9_Mode22</th>
#       <th>fn10</th>
#       <th>fn3</th>
#       <th>zeta5</th>
#       <th>fn1</th>
#       <th>Real_Comp7_Mode6</th>
#       <th>Real_Comp7_Mode18</th>
#       <th>Imag_Comp5_Mode17</th>
#       <th>Imag_Comp11_Mode11</th>
#       <th>Imag_Comp11_Mode21</th>
#       <th>zeta22</th>
#       <th>Imag_Comp10_Mode25</th>
#       <th>Imag_Comp8_Mode20</th>
#       <th>Real_Comp5_Mode8</th>
#       <th>Imag_Comp4_Mode12</th>
#       <th>Real_Comp2_Mode3</th>
#       <th>Imag_Comp7_Mode5</th>
#       <th>Imag_Comp8_Mode2</th>
#       <th>Real_Comp9_Mode10</th>
#       <th>Imag_Comp8_Mode16</th>
#       <th>Imag_Comp4_Mode15</th>
#       <th>Imag_Comp1_Mode8</th>
#       <th>Imag_Comp2_Mode8</th>
#       <th>Real_Comp10_Mode13</th>
#       <th>Imag_Comp6_Mode7</th>
#       <th>Imag_Comp2_Mode15</th>
#       <th>Imag_Comp11_Mode16</th>
#       <th>Imag_Comp8_Mode4</th>
#       <th>Imag_Comp3_Mode19</th>
#       <th>Imag_Comp8_Mode10</th>
#       <th>Real_Comp7_Mode5</th>
#       <th>Real_Comp7_Mode23</th>
#       <th>Real_Comp3_Mode10</th>
#       <th>Real_Comp9_Mode6</th>
#       <th>Imag_Comp10_Mode18</th>
#       <th>Imag_Comp9_Mode16</th>
#       <th>Imag_Comp8_Mode6</th>
#       <th>Real_Comp7_Mode3</th>
#       <th>Real_Comp4_Mode18</th>
#       <th>Real_Comp2_Mode9</th>
#       <th>Imag_Comp5_Mode18</th>
#       <th>Real_Comp1_Mode3</th>
#       <th>Real_Comp9_Mode21</th>
#       <th>Real_Comp2_Mode20</th>
#       <th>Real_Comp7_Mode21</th>
#       <th>fn2</th>
#       <th>Imag_Comp8_Mode1</th>
#       <th>Imag_Comp3_Mode7</th>
#       <th>Imag_Comp1_Mode21</th>
#       <th>Real_Comp8_Mode16</th>
#       <th>Real_Comp3_Mode22</th>
#       <th>Real_Comp8_Mode13</th>
#       <th>Imag_Comp6_Mode25</th>
#       <th>Real_Comp2_Mode4</th>
#       <th>Imag_Comp3_Mode9</th>
#       <th>Imag_Comp2_Mode21</th>
#       <th>Real_Comp9_Mode14</th>
#       <th>Real_Comp2_Mode14</th>
#       <th>Real_Comp5_Mode7</th>
#       <th>zeta16</th>
#       <th>Imag_Comp4_Mode4</th>
#       <th>Real_Comp4_Mode10</th>
#       <th>Real_Comp1_Mode1</th>
#       <th>Imag_Comp4_Mode1</th>
#       <th>Imag_Comp5_Mode20</th>
#       <th>Imag_Comp1_Mode10</th>
#       <th>Imag_Comp1_Mode2</th>
#       <th>Imag_Comp11_Mode2</th>
#       <th>Real_Comp4_Mode20</th>
#       <th>Imag_Comp3_Mode16</th>
#       <th>Imag_Comp9_Mode10</th>
#       <th>Real_Comp11_Mode12</th>
#       <th>Imag_Comp6_Mode13</th>
#       <th>zeta17</th>
#       <th>Imag_Comp1_Mode9</th>
#       <th>Imag_Comp5_Mode3</th>
#       <th>Real_Comp9_Mode11</th>
#       <th>Real_Comp6_Mode17</th>
#       <th>Real_Comp7_Mode25</th>
#       <th>Imag_Comp9_Mode20</th>
#       <th>Real_Comp5_Mode18</th>
#       <th>Real_Comp11_Mode22</th>
#       <th>Imag_Comp4_Mode2</th>
#       <th>Imag_Comp2_Mode18</th>
#       <th>Imag_Comp3_Mode12</th>
#       <th>Imag_Comp5_Mode8</th>
#       <th>Real_Comp9_Mode20</th>
#       <th>Imag_Comp6_Mode18</th>
#       <th>Real_Comp1_Mode21</th>
#       <th>zeta4</th>
#       <th>Imag_Comp10_Mode2</th>
#       <th>Real_Comp5_Mode10</th>
#       <th>fn11</th>
#       <th>Real_Comp6_Mode25</th>
#       <th>Imag_Comp7_Mode11</th>
#       <th>Real_Comp9_Mode23</th>
#       <th>Imag_Comp10_Mode1</th>
#       <th>Real_Comp4_Mode7</th>
#       <th>fn22</th>
#       <th>Imag_Comp3_Mode23</th>
#       <th>Real_Comp7_Mode1</th>
#       <th>Imag_Comp5_Mode23</th>
#       <th>Real_Comp5_Mode2</th>
#       <th>Real_Comp8_Mode10</th>
#       <th>Imag_Comp2_Mode5</th>
#       <th>Imag_Comp6_Mode19</th>
#       <th>Real_Comp10_Mode15</th>
#       <th>Real_Comp6_Mode19</th>
#       <th>Imag_Comp5_Mode13</th>
#       <th>fn4</th>
#       <th>Real_Comp3_Mode25</th>
#       <th>Imag_Comp1_Mode13</th>
#       <th>Imag_Comp1_Mode12</th>
#       <th>Imag_Comp4_Mode25</th>
#       <th>Real_Comp6_Mode24</th>
#       <th>Real_Comp6_Mode18</th>
#       <th>Real_Comp4_Mode23</th>
#       <th>Real_Comp2_Mode7</th>
#       <th>Real_Comp10_Mode8</th>
#       <th>Real_Comp8_Mode17</th>
#       <th>Imag_Comp2_Mode3</th>
#       <th>Real_Comp5_Mode4</th>
#       <th>Imag_Comp5_Mode7</th>
#       <th>Imag_Comp4_Mode9</th>
#       <th>Imag_Comp4_Mode17</th>
#       <th>Real_Comp6_Mode15</th>
#       <th>Real_Comp1_Mode5</th>
#       <th>Real_Comp1_Mode11</th>
#       <th>Real_Comp7_Mode7</th>
#       <th>Real_Comp7_Mode15</th>
#       <th>Imag_Comp2_Mode4</th>
#       <th>Subject</th>
#       <th>Real_Comp2_Mode15</th>
#       <th>Real_Comp8_Mode9</th>
#       <th>Imag_Comp7_Mode10</th>
#       <th>Real_Comp3_Mode18</th>
#       <th>Imag_Comp1_Mode11</th>
#       <th>Imag_Comp1_Mode20</th>
#       <th>Real_Comp6_Mode8</th>
#       <th>Imag_Comp4_Mode21</th>
#       <th>Imag_Com

# %%
# max_log_y = np.log(np.max(df_raw['subject'])*1.2)
# y_range = torch.tensor([0, max_log_y])

# %%
# learn = tabular_learner(data, layers=[2000,500], ps=[0.001,0.01], emb_drop=0.04, metrics=accuracy, emb_szs={'emotion_quad': 4})
learn = tabular_learner(data, layers=[2000,500], ps=[0.001,0.01], emb_drop=0.04, metrics=accuracy)

# %%
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(5, 4)
#   )
#   (emb_drop): Dropout(p=0.04, inplace=False)
#   (bn_cont): BatchNorm1d(601, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=605, out_features=2000, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(2000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.001, inplace=False)
#     (4): Linear(in_features=2000, out_features=500, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.01, inplace=False)
#     (8): Linear(in_features=500, out_features=40, bias=True)
#   )
# )

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       71.43% [5/7 00:02<00:01]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.848149</td>
#       <td>#na#</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.827960</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.710253</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.974432</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.551927</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='16', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       31.25% [5/16 00:00<00:00 4.3788]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, 1e-2, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.114402</td>
#       <td>4.280719</td>
#       <td>0.035156</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.864978</td>
#       <td>5.616843</td>
#       <td>0.039062</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.839146</td>
#       <td>5.832945</td>
#       <td>0.027344</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.180470</td>
#       <td>5.795270</td>
#       <td>0.007812</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.783407</td>
#       <td>5.734099</td>
#       <td>0.007812</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='4' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       57.14% [4/7 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.027516</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.026722</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.026065</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.021708</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='13' class='' max='16', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       81.25% [13/16 00:00<00:00 0.0357]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(15, 1e-2, wd=0.5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.024726</td>
#       <td>5.657798</td>
#       <td>0.007812</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.018560</td>
#       <td>5.458223</td>
#       <td>0.015625</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.014206</td>
#       <td>5.160795</td>
#       <td>0.011719</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.011869</td>
#       <td>4.833906</td>
#       <td>0.011719</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.010957</td>
#       <td>4.631444</td>
#       <td>0.011719</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.010441</td>
#       <td>4.520473</td>
#       <td>0.023438</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.010126</td>
#       <td>4.470852</td>
#       <td>0.019531</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.009418</td>
#       <td>4.440155</td>
#       <td>0.023438</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.008758</td>
#       <td>4.428894</td>
#       <td>0.019531</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.008101</td>
#       <td>4.430522</td>
#       <td>0.019531</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.007474</td>
#       <td>4.453962</td>
#       <td>0.019531</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.006896</td>
#       <td>4.464066</td>
#       <td>0.019531</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.006367</td>
#       <td>4.483799</td>
#       <td>0.019531</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.005981</td>
#       <td>4.501696</td>
#       <td>0.019531</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.005682</td>
#       <td>4.505461</td>
#       <td>0.019531</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>emotion_quad</th>
#       <th>Real_Comp10_Mode10</th>
#       <th>Imag_Comp4_Mode13</th>
#       <th>Imag_Comp2_Mode13</th>
#       <th>Imag_Comp6_Mode20</th>
#       <th>Real_Comp7_Mode11</th>
#       <th>Real_Comp1_Mode17</th>
#       <th>Imag_Comp1_Mode23</th>
#       <th>Real_Comp4_Mode9</th>
#       <th>Imag_Comp11_Mode5</th>
#       <th>Imag_Comp7_Mode6</th>
#       <th>Imag_Comp5_Mode16</th>
#       <th>Real_Comp3_Mode1</th>
#       <th>Real_Comp9_Mode7</th>
#       <th>Real_Comp9_Mode5</th>
#       <th>Imag_Comp7_Mode9</th>
#       <th>Imag_Comp2_Mode6</th>
#       <th>Real_Comp11_Mode25</th>
#       <th>Real_Comp1_Mode8</th>
#       <th>Imag_Comp7_Mode19</th>
#       <th>Imag_Comp4_Mode23</th>
#       <th>Imag_Comp9_Mode7</th>
#       <th>Imag_Comp5_Mode10</th>
#       <th>Real_Comp9_Mode1</th>
#       <th>Real_Comp8_Mode19</th>
#       <th>Real_Comp6_Mode22</th>
#       <th>Real_Comp11_Mode4</th>
#       <th>Real_Comp3_Mode9</th>
#       <th>Real_Comp11_Mode9</th>
#       <th>Real_Comp10_Mode7</th>
#       <th>Real_Comp8_Mode18</th>
#       <th>Imag_Comp2_Mode23</th>
#       <th>Imag_Comp11_Mode3</th>
#       <th>Imag_Comp9_Mode11</th>
#       <th>Real_Comp3_Mode23</th>
#       <th>Imag_Comp9_Mode4</th>
#       <th>Imag_Comp2_Mode17</th>
#       <th>Imag_Comp2_Mode24</th>
#       <th>Real_Comp4_Mode22</th>
#       <th>Imag_Comp6_Mode17</th>
#       <th>Real_Comp10_Mode16</th>
#       <th>Imag_Comp5_Mode22</th>
#       <th>Imag_Comp10_Mode9</th>
#       <th>fn20</th>
#       <th>fn13</th>
#       <th>Real_Comp3_Mode5</th>
#       <th>Imag_Comp11_Mode17</th>
#       <th>Real_Comp5_Mode9</th>
#       <th>Imag_Comp6_Mode10</th>
#       <th>Imag_Comp4_Mode11</th>
#       <th>Imag_Comp3_Mode11</th>
#       <th>Imag_Comp7_Mode7</th>
#       <th>Imag_Comp3_Mode22</th>
#       <th>Imag_Comp6_Mode9</th>
#       <th>Real_Comp5_Mode14</th>
#       <th>Imag_Comp11_Mode6</th>
#       <th>Real_Comp4_Mode4</th>
#       <th>zeta11</th>
#       <th>Real_Comp3_Mode8</th>
#       <th>Imag_Comp11_Mode4</th>
#       <th>Imag_Comp4_Mode8</th>
#       <th>Imag_Comp9_Mode23</th>
#       <th>Real_Comp8_Mode5</th>
#       <th>Imag_Comp3_Mode10</th>
#       <th>Real_Comp8_Mode1</th>
#       <th>Imag_Comp1_Mode1</th>
#       <th>fn5</th>
#       <th>Real_Comp4_Mode6</th>
#       <th>Real_Comp2_Mode19</th>
#       <th>Imag_Comp9_Mode18</th>
#       <th>zeta21</th>
#       <th>Real_Comp9_Mode19</th>
#       <th>Real_Comp9_Mode13</th>
#       <th>Imag_Comp5_Mode24</th>
#       <th>zeta10</th>
#       <th>Imag_Comp4_Mode5</th>
#       <th>Imag_Comp3_Mode24</th>
#       <th>Imag_Comp11_Mode15</th>
#       <th>Imag_Comp4_Mode16</th>
#       <th>Real_Comp3_Mode2</th>
#       <th>zeta7</th>
#       <th>fn16</th>
#       <th>Imag_Comp8_Mode7</th>
#       <th>Imag_Comp10_Mode11</th>
#       <th>Real_Comp6_Mode16</th>
#       <th>Real_Comp11_Mode3</th>
#       <th>Real_Comp7_Mode16</th>
#       <th>Real_Comp11_Mode16</th>
#       <th>Imag_Comp11_Mode7</th>
#       <th>Imag_Comp3_Mode13</th>
#       <th>Real_Comp8_Mode11</th>
#       <th>Imag_Comp1_Mode15</th>
#       <th>Real_Comp7_Mode19</th>
#       <th>Imag_Comp2_Mode20</th>
#       <th>Real_Comp5_Mode3</th>
#       <th>Real_Comp5_Mode11</th>
#       <th>Real_Comp7_Mode22</th>
#       <th>Real_Comp5_Mode25</th>
#       <th>Imag_Comp6_Mode24</th>
#       <th>Real_Comp4_Mode8</th>
#       <th>Imag_Comp8_Mode22</th>
#       <th>Real_Comp8_Mode6</th>
#       <th>Imag_Comp10_Mode3</th>
#       <th>Real_Comp9_Mode25</th>
#       <th>Imag_Comp5_Mode12</th>
#       <th>Real_Comp2_Mode24</th>
#       <th>Imag_Comp10_Mode23</th>
#       <th>Imag_Comp11_Mode13</th>
#       <th>Imag_Comp2_Mode14</th>
#       <th>Real_Comp9_Mode22</th>
#       <th>fn10</th>
#       <th>fn3</th>
#       <th>zeta5</th>
#       <th>fn1</th>
#       <th>Real_Comp7_Mode6</th>
#       <th>Real_Comp7_Mode18</th>
#       <th>Imag_Comp5_Mode17</th>
#       <th>Imag_Comp11_Mode11</th>
#       <th>Imag_Comp11_Mode21</th>
#       <th>zeta22</th>
#       <th>Imag_Comp10_Mode25</th>
#       <th>Imag_Comp8_Mode20</th>
#       <th>Real_Comp5_Mode8</th>
#       <th>Imag_Comp4_Mode12</th>
#       <th>Real_Comp2_Mode3</th>
#       <th>Imag_Comp7_Mode5</th>
#       <th>Imag_Comp8_Mode2</th>
#       <th>Real_Comp9_Mode10</th>
#       <th>Imag_Comp8_Mode16</th>
#       <th>Imag_Comp4_Mode15</th>
#       <th>Imag_Comp1_Mode8</th>
#       <th>Imag_Comp2_Mode8</th>
#       <th>Real_Comp10_Mode13</th>
#       <th>Imag_Comp6_Mode7</th>
#       <th>Imag_Comp2_Mode15</th>
#       <th>Imag_Comp11_Mode16</th>
#       <th>Imag_Comp8_Mode4</th>
#       <th>Imag_Comp3_Mode19</th>
#       <th>Imag_Comp8_Mode10</th>
#       <th>Real_Comp7_Mode5</th>
#       <th>Real_Comp7_Mode23</th>
#       <th>Real_Comp3_Mode10</th>
#       <th>Real_Comp9_Mode6</th>
#       <th>Imag_Comp10_Mode18</th>
#       <th>Imag_Comp9_Mode16</th>
#       <th>Imag_Comp8_Mode6</th>
#       <th>Real_Comp7_Mode3</th>
#       <th>Real_Comp4_Mode18</th>
#       <th>Real_Comp2_Mode9</th>
#       <th>Imag_Comp5_Mode18</th>
#       <th>Real_Comp1_Mode3</th>
#       <th>Real_Comp9_Mode21</th>
#       <th>Real_Comp2_Mode20</th>
#       <th>Real_Comp7_Mode21</th>
#       <th>fn2</th>
#       <th>Imag_Comp8_Mode1</th>
#       <th>Imag_Comp3_Mode7</th>
#       <th>Imag_Comp1_Mode21</th>
#       <th>Real_Comp8_Mode16</th>
#       <th>Real_Comp3_Mode22</th>
#       <th>Real_Comp8_Mode13</th>
#       <th>Imag_Comp6_Mode25</th>
#       <th>Real_Comp2_Mode4</th>
#       <th>Imag_Comp3_Mode9</th>
#       <th>Imag_Comp2_Mode21</th>
#       <th>Real_Comp9_Mode14</th>
#       <th>Real_Comp2_Mode14</th>
#       <th>Real_Comp5_Mode7</th>
#       <th>zeta16</th>
#       <th>Imag_Comp4_Mode4</th>
#       <th>Real_Comp4_Mode10</th>
#       <th>Real_Comp1_Mode1</th>
#       <th>Imag_Comp4_Mode1</th>
#       <th>Imag_Comp5_Mode20</th>
#       <th>Imag_Comp1_Mode10</th>
#       <th>Imag_Comp1_Mode2</th>
#       <th>Imag_Comp11_Mode2</th>
#       <th>Real_Comp4_Mode20</th>
#       <th>Imag_Comp3_Mode16</th>
#       <th>Imag_Comp9_Mode10</th>
#       <th>Real_Comp11_Mode12</th>
#       <th>Imag_Comp6_Mode13</th>
#       <th>zeta17</th>
#       <th>Imag_Comp1_Mode9</th>
#       <th>Imag_Comp5_Mode3</th>
#       <th>Real_Comp9_Mode11</th>
#       <th>Real_Comp6_Mode17</th>
#       <th>Real_Comp7_Mode25</th>
#       <th>Imag_Comp9_Mode20</th>
#       <th>Real_Comp5_Mode18</th>
#       <th>Real_Comp11_Mode22</th>
#       <th>Imag_Comp4_Mode2</th>
#       <th>Imag_Comp2_Mode18</th>
#       <th>Imag_Comp3_Mode12</th>
#       <th>Imag_Comp5_Mode8</th>
#       <th>Real_Comp9_Mode20</th>
#       <th>Imag_Comp6_Mode18</th>
#       <th>Real_Comp1_Mode21</th>
#       <th>zeta4</th>
#       <th>Imag_Comp10_Mode2</th>
#       <th>Real_Comp5_Mode10</th>
#       <th>fn11</th>
#       <th>Real_Comp6_Mode25</th>
#       <th>Imag_Comp7_Mode11</th>
#       <th>Real_Comp9_Mode23</th>
#       <th>Imag_Comp10_Mode1</th>
#       <th>Real_Comp4_Mode7</th>
#       <th>fn22</th>
#       <th>Imag_Comp3_Mode23</th>
#       <th>Real_Comp7_Mode1</th>
#       <th>Imag_Comp5_Mode23</th>
#       <th>Real_Comp5_Mode2</th>
#       <th>Real_Comp8_Mode10</th>
#       <th>Imag_Comp2_Mode5</th>
#       <th>Imag_Comp6_Mode19</th>
#       <th>Real_Comp10_Mode15</th>
#       <th>Real_Comp6_Mode19</th>
#       <th>Imag_Comp5_Mode13</th>
#       <th>fn4</th>
#       <th>Real_Comp3_Mode25</th>
#       <th>Imag_Comp1_Mode13</th>
#       <th>Imag_Comp1_Mode12</th>
#       <th>Imag_Comp4_Mode25</th>
#       <th>Real_Comp6_Mode24</th>
#       <th>Real_Comp6_Mode18</th>
#       <th>Real_Comp4_Mode23</th>
#       <th>Real_Comp2_Mode7</th>
#       <th>Real_Comp10_Mode8</th>
#       <th>Real_Comp8_Mode17</th>
#       <th>Imag_Comp2_Mode3</th>
#       <th>Real_Comp5_Mode4</th>
#       <th>Imag_Comp5_Mode7</th>
#       <th>Imag_Comp4_Mode9</th>
#       <th>Imag_Comp4_Mode17</th>
#       <th>Real_Comp6_Mode15</th>
#       <th>Real_Comp1_Mode5</th>
#       <th>Real_Comp1_Mode11</th>
#       <th>Real_Comp7_Mode7</th>
#       <th>Real_Comp7_Mode15</th>
#       <th>Imag_Comp2_Mode4</th>
#       <th>Subject</th>
#       <th>Real_Comp2_Mode15</th>
#       <th>Real_Comp8_Mode9</th>
#       <th>Imag_Comp7_Mode10</th>
#       <th>Real_Comp3_Mode18</th>
#       <th>Imag_Comp1_Mode11</th>
#       <th>Imag_Comp1_Mode20</th>
#       <th>Real_Comp6_Mode8</th>
#       <th>Imag_Comp4_Mode21</th>
#       <th>Imag_Com

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)

# %%
interp.plot_confusion_matrix(figsize=(10,10))
