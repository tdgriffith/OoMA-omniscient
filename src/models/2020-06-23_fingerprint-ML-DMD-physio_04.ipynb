# %% [markdown]
# # ANN to Predict Subject
# Using modal representation, can we tell which subject it came from with DMD modes? Trying a [second data set](https://www.physionet.org/content/eegmmidb/1.0.0/)
#
# - w/ 60 modes
# - split each trial into eight smaller trials
# - 32 channels

# %% [markdown]
# Setup: Javascript and ipynb stuff

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# %%javascript
# utils.load_extension('collapsible_headings/main')
# utils.load_extension('hide_input/main')
# utils.load_extension('execute_time/ExecuteTime')
# utils.load_extension('code_prettify/code_prettify')
# utils.load_extension('scroll_down/main')
# utils.load_extension('jupyter-js-widgets/extension')

# %% [markdown]
# ## Load Functions

# %%
import warnings; warnings.simplefilter('ignore')

# %%
from fastai.vision import *
import os
import numpy as np
import pandas as pd
import pickle
import glob

# %%
path=pathlib.Path('/media/tris/tris_files/EEG_datasets/physionet.org/processed/DMD_phys_2')
path
# Out:
# PosixPath('/media/tris/tris_files/EEG_datasets/physionet.org/processed/DMD_phys_2')

# %% [markdown]
# ## Set filenames and labels

# %%
# filenames=[]
# subject_labels=[]
# for n in range (1,110):
#     for i in range (1,43):
#         filename='S'+str(n)+'T'+str(i)
#         filenames.append(filename)
#         subject_label=n
#         subject_labels.append(subject_label)
# df=pd.DataFrame()
# df['file_name']=filenames
# df['subject_label']=subject_labels
# # df=df[['file_name','valence','arousal','dominance','liking']]
# df=df[['file_name','subject_label']]
# df

# %%
filenames = glob.glob('/media/tris/tris_files/EEG_datasets/physionet.org/processed/DMD_phys_2/robots*')

# %%
names = [os.path.splitext(os.path.basename(x))[0] for x in glob.glob('/media/tris/tris_files/EEG_datasets/physionet.org/processed/DMD_phys_2/robots/*')]

# %%
subject=[]
for i in range(0,len(names)):
    if names[i][2]=='T':
        subject.append(names[i][1])
    elif names[i][3]=='T':
        subject.append(names[i][1:3])
    elif names[i][4]=='T':
        subject.append(names[i][1:4])

# %%
df1=DataFrame(names,columns=['filename'])
df2=DataFrame(subject,columns=['subject'])
frames=[df1,df2]
df=pd.concat(frames, axis=1)
df.tail()
# Out:
#      filename subject
# 6426   S69T15      69
# 6427   S32T60      32
# 6428   S16T56      16
# 6429   S73T39      73
# 6430   S72T22      72

# %%
path=pathlib.Path('/media/tris/tris_files/EEG_datasets/physionet.org/processed/DMD_phys_2')
path
# Out:
# PosixPath('/media/tris/tris_files/EEG_datasets/physionet.org/processed/DMD_phys_2')

# %%
df.to_csv(path/'labels_proc.csv', index=False)

# %% [markdown]
# ## Data loader

# %%
path=pathlib.Path('/media/tris/tris_files/EEG_datasets/physionet.org/processed/DMD_phys_2')
path
# Out:
# PosixPath('/media/tris/tris_files/EEG_datasets/physionet.org/processed/DMD_phys_2')

# %%
df = pd.read_csv(path/'labels_proc.csv') #load labels
df.tail()
# Out:
#      filename  subject
# 6426   S69T15       69
# 6427   S32T60       32
# 6428   S16T56       16
# 6429   S73T39       73
# 6430   S72T22       72

# %% [markdown]
# ## Data loader

# %%
src = (ImageList.from_csv(path, 'labels_proc.csv', folder='robots', suffix='.png')
       .split_by_rand_pct(0.2)
       .label_from_df(cols=['subject'],label_cls=CategoryList))

# %%
tfms=get_transforms()
tf_final=[[tfms[0][0],tfms[0][4],tfms[0][5],tfms[0][6]],None]

# %%
data = (src.transform(tf_final, size=200)
        .databunch(bs=4).normalize())

# %%
data.show_batch(rows=4, figsize=(12,9))

# %% [markdown]
# ## Setup Network

# %%
learn = cnn_learner(data, models.resnet34, metrics=accuracy)

# %%
learn.summary()
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 100, 100]       9,408      False
# ______________________________________________________________________
# BatchNorm2d          [64, 100, 100]       128        True
# ______________________________________________________________________
# ReLU                 [64, 100, 100]       0          False
# ______________________________________________________________________
# MaxPool2d            [64, 50, 50]         0          False
# ______________________________________________________________________
# Conv2d               [64, 50, 50]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 50, 50]         128        True
# ______________________________________________________________________
# ReLU                 [64, 50, 50]         0          False
# ______________________________________________________________________
# Conv2d               [64, 50, 50]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 50, 50]         128        True
# ______________________________________________________________________
# Conv2d               [64, 50, 50]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 50, 50]         128        True
# ______________________________________________________________________
# ReLU                 [64, 50, 50]         0          False
# ______________________________________________________________________
# Conv2d               [64, 50, 50]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 50, 50]         128        True
# ______________________________________________________________________
# Conv2d               [64, 50, 50]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 50, 50]         128        True
# ______________________________________________________________________
# ReLU                 [64, 50, 50]         0          False
# ______________________________________________________________________
# Conv2d               [64, 50, 50]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 50, 50]         128        True
# ______________________________________________________________________
# Conv2d               [128, 25, 25]        73,728     False
# ______________________________________________________________________
# BatchNorm2d          [128, 25, 25]        256        True
# ______________________________________________________________________
# ReLU                 [128, 25, 25]        0          False
# ______________________________________________________________________
# Conv2d               [128, 25, 25]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 25, 25]        256        True
# ______________________________________________________________________
# Conv2d               [128, 25, 25]        8,192      False
# ______________________________________________________________________
# BatchNorm2d          [128, 25, 25]        256        True
# ______________________________________________________________________
# Conv2d               [128, 25, 25]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 25, 25]        256        True
# ______________________________________________________________________
# ReLU                 [128, 25, 25]        0          False
# ______________________________________________________________________
# Conv2d               [128, 25, 25]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 25, 25]        256        True
# ______________________________________________________________________
# Conv2d               [128, 25, 25]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 25, 25]        256        True
# ______________________________________________________________________
# ReLU                 [128, 25, 25]        0          False
# ______________________________________________________________________
# Conv2d               [128, 25, 25]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 25, 25]        256        True
# ______________________________________________________________________
# Conv2d               [128, 25, 25]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 25, 25]        256        True
# ______________________________________________________________________
# ReLU                 [128, 25, 25]        0          False
# ______________________________________________________________________
# Conv2d               [128, 25, 25]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 25, 25]        256        True
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        294,912    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# ReLU                 [256, 13, 13]        0          False
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        32,768     False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# ReLU                 [256, 13, 13]        0          False
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# ReLU                 [256, 13, 13]        0          False
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# ReLU                 [256, 13, 13]        0          False
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# ReLU                 [256, 13, 13]        0          False
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# ReLU                 [256, 13, 13]        0          False
# ______________________________________________________________________
# Conv2d               [256, 13, 13]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 13, 13]        512        True
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          1,179,648  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 7, 7]          0          False
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          131,072    False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 7, 7]          0          False
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# ReLU                 [512, 7, 7]          0          False
# ______________________________________________________________________
# Conv2d               [512, 7, 7]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 7, 7]          1,024      True
# ______________________________________________________________________
# AdaptiveAvgPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [512, 1, 1]          0          False
# ______________________________________________________________________
# Flatten              [1024]               0          False
# ______________________________________________________________________
# BatchNorm1d          [1024]               2,048      True
# ______________________________________________________________________
# Dropout              [1024]               0          False
# ______________________________________________________________________
# Linear               [512]                524,800    True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [109]                55,917     True
# ______________________________________________________________________
#
# Total params: 21,868,461
# Total trainable params: 600,813
# Total non-trainable params: 21,267,648
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='86' class='' max='1286', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.69% [86/1286 00:04<00:59 14.0279]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ## Train last layers

# %%
lr = 1e-4
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.407620</td>
#       <td>5.212826</td>
#       <td>0.013997</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.932861</td>
#       <td>4.838641</td>
#       <td>0.026439</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.820277</td>
#       <td>4.648161</td>
#       <td>0.037325</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.552932</td>
#       <td>4.521242</td>
#       <td>0.051322</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>5.708499</td>
#       <td>4.566200</td>
#       <td>0.041991</td>
#       <td>01:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.show_results()

# %% [markdown]
# ## Train the whole network

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='87' class='' max='1286', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.77% [87/1286 00:04<00:59 17.7713]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-4
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.615865</td>
#       <td>4.547452</td>
#       <td>0.043546</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>5.452476</td>
#       <td>4.291969</td>
#       <td>0.080871</td>
#       <td>01:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.872047</td>
#       <td>4.148076</td>
#       <td>0.092535</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>5.049347</td>
#       <td>3.998724</td>
#       <td>0.105754</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.940082</td>
#       <td>4.001345</td>
#       <td>0.108087</td>
#       <td>01:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
data = (src.transform(tf_final, size=512)
        .databunch(bs=4).normalize())

# %%
learn.data=data

# %%
learn.freeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='87' class='' max='1286', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.77% [87/1286 00:07<01:49 15.4718]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-2
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.377484</td>
#       <td>4.548396</td>
#       <td>0.048989</td>
#       <td>02:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.675765</td>
#       <td>4.134668</td>
#       <td>0.067652</td>
#       <td>02:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.322861</td>
#       <td>3.576028</td>
#       <td>0.146190</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.823285</td>
#       <td>3.622764</td>
#       <td>0.279938</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.564419</td>
#       <td>4.216961</td>
#       <td>0.355365</td>
#       <td>02:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.867013</td>
#       <td>7.679685</td>
#       <td>0.267496</td>
#       <td>02:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.862395</td>
#       <td>5.273993</td>
#       <td>0.260498</td>
#       <td>02:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.430906</td>
#       <td>24.969770</td>
#       <td>0.422240</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.987125</td>
#       <td>5.326338</td>
#       <td>0.646967</td>
#       <td>02:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.614045</td>
#       <td>2.144356</td>
#       <td>0.713064</td>
#       <td>02:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='84' class='' max='1286', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.53% [84/1286 00:09<02:21 6.1229]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-4
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.633837</td>
#       <td>5.674519</td>
#       <td>0.707621</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.392033</td>
#       <td>4.999889</td>
#       <td>0.748834</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.121501</td>
#       <td>3.488216</td>
#       <td>0.793935</td>
#       <td>02:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.987886</td>
#       <td>9.076536</td>
#       <td>0.751944</td>
#       <td>02:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.042341</td>
#       <td>5.249332</td>
#       <td>0.770607</td>
#       <td>02:45</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.freeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='84' class='' max='1286', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.53% [84/1286 00:07<01:43 5.3108]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-3
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.939352</td>
#       <td>9.979654</td>
#       <td>0.772162</td>
#       <td>02:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.816660</td>
#       <td>2.609112</td>
#       <td>0.821151</td>
#       <td>02:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.684891</td>
#       <td>3.609136</td>
#       <td>0.869362</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.586755</td>
#       <td>1.727061</td>
#       <td>0.877138</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.599432</td>
#       <td>2.960079</td>
#       <td>0.871695</td>
#       <td>02:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(10, slice(lr), wd=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.980655</td>
#       <td>0.458412</td>
#       <td>0.937014</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.048729</td>
#       <td>0.407007</td>
#       <td>0.929238</td>
#       <td>02:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.938268</td>
#       <td>0.293172</td>
#       <td>0.950233</td>
#       <td>02:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.966782</td>
#       <td>0.256165</td>
#       <td>0.958009</td>
#       <td>02:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.993877</td>
#       <td>0.305638</td>
#       <td>0.944790</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.941165</td>
#       <td>0.227924</td>
#       <td>0.953344</td>
#       <td>02:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.727007</td>
#       <td>0.210823</td>
#       <td>0.963453</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.773873</td>
#       <td>0.245621</td>
#       <td>0.954121</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.644183</td>
#       <td>0.210586</td>
#       <td>0.962675</td>
#       <td>02:07</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.586200</td>
#       <td>0.205500</td>
#       <td>0.962675</td>
#       <td>02:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(5, slice(lr), wd=0.1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.670881</td>
#       <td>0.190921</td>
#       <td>0.967341</td>
#       <td>02:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.933366</td>
#       <td>0.250692</td>
#       <td>0.957232</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.688395</td>
#       <td>0.261217</td>
#       <td>0.960342</td>
#       <td>02:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.687719</td>
#       <td>0.182395</td>
#       <td>0.972006</td>
#       <td>02:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.608552</td>
#       <td>0.186958</td>
#       <td>0.966563</td>
#       <td>02:06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Interpret and Results

# %%
learn.show_results()

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)

# %%
interp.plot_confusion_matrix(figsize=(20,20))

# %%
interp.plot_top_losses(4)

# %% [markdown]
# # Yes! Try with a densenet and deeper resnet, but these are very good
