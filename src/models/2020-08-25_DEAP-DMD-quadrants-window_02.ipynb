# %% [markdown]
# # ANN to Predict a Quadrant
# Using modal representation, can we imrprove on Santamaria-Granados, Luz, et al. "Using deep convolutional neural network for emotion detection on a physiological signals dataset (AMIGOS)." IEEE Access 7 (2018): 57-67.
#
# Another step forward from fingerprints, single subject??
#
# Single, w\ augmentation

# %% [markdown]
# Setup: Javascript and ipynb stuff

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# %%javascript
# utils.load_extension('collapsible_headings/main')
# utils.load_extension('hide_input/main')
# utils.load_extension('autosavetime/main')
# utils.load_extension('execute_time/ExecuteTime')
# utils.load_extension('code_prettify/code_prettify')
# utils.load_extension('scroll_down/main')
# utils.load_extension('jupyter-js-widgets/extension')

# %% [markdown]
# ## Load Functions

# %%
from fastai.vision import *
import os
import numpy as np
import pandas as pd
import pickle
import warnings; warnings.simplefilter('ignore')

# %%
path=pathlib.Path('/home/tris/Documents/EEG_data/DMD_DEAP')
path
# Out:
# PosixPath('/home/tris/Documents/EEG_data/DMD_DEAP')

# %% [markdown]
# ## Load Original Data Labels

# %%
path = '/media/tris/tris_files/EEG_datasets/DEAP_data_preprocessed_python/s01.dat'
df_read = pickle.load(open(path, 'rb'), encoding='latin1')
labels=df_read['labels']
df_tmp = pd.DataFrame(labels, columns=['valence','arousal','dominance','liking'])
df=df_tmp
for n in range (2,10):
    path = '/media/tris/tris_files/EEG_datasets/DEAP_data_preprocessed_python/s0'+str(n)+'.dat'
    df_read = pickle.load(open(path, 'rb'), encoding='latin1')
    labels=df_read['labels']
    df_tmp = pd.DataFrame(labels, columns=['valence','arousal','dominance','liking'])
    df=df.append(df_tmp, ignore_index=True)
for n in range (10,33):
    path = '/media/tris/tris_files/EEG_datasets/DEAP_data_preprocessed_python/s'+str(n)+'.dat'
    df_read = pickle.load(open(path, 'rb'), encoding='latin1')
    labels=df_read['labels']
    df_tmp = pd.DataFrame(labels, columns=['valence','arousal','dominance','liking'])
    df=df.append(df_tmp, ignore_index=True)

# %%
df=df.div(9) #normalize
df.head()
# Out:
#     valence   arousal  dominance    liking
# 0  0.856667  0.844444   0.766667  0.870000
# 1  0.900000  0.812222   0.808889  0.941111
# 2  0.953333  0.837778   1.000000  0.786667
# 3  0.548889  0.667778   0.680000  0.895556
# 4  0.773333  0.435556   0.798889  0.672222

# %%
df=df.loc[df.index.repeat(4)].reset_index(drop=True)

# %%
df.tail()
# Out:
#        valence   arousal  dominance    liking
# 5115  0.443333  0.796667   0.538889  0.111111
# 5116  0.794444  0.447778   1.000000  0.208889
# 5117  0.794444  0.447778   1.000000  0.208889
# 5118  0.794444  0.447778   1.000000  0.208889
# 5119  0.794444  0.447778   1.000000  0.208889

# %% [markdown]
# ## Set filenames and labels

# %%
filenames=[]
subject_labels=[]
for n in range (0,9):
    for i in range (0,9):
        filename='S'+str(n+1)+'T'+str(i+1)
        filenames.append(filename)
        subject_label=n+1
        subject_labels.append(subject_label)
    for i in range (9,160):
        filename='S'+str(n+1)+'T'+str(i+1)
        filenames.append(filename)
        subject_label=n+1
        subject_labels.append(subject_label)
for n in range (9,32):
    for i in range (0,9):
        filename='S'+str(n+1)+'T'+str(i+1)
        filenames.append(filename)
        subject_label=n+1
        subject_labels.append(subject_label)
    for i in range (9,160):
        filename='S'+str(n+1)+'T'+str(i+1)
        filenames.append(filename)
        subject_label=n+1
        subject_labels.append(subject_label)

# %%
df['file_name']=filenames
df['subject_label']=subject_labels
df=df[['file_name','subject_label','valence','arousal']]
df.tail()
# Out:
#      file_name  subject_label   valence   arousal
# 5115   S32T156             32  0.443333  0.796667
# 5116   S32T157             32  0.794444  0.447778
# 5117   S32T158             32  0.794444  0.447778
# 5118   S32T159             32  0.794444  0.447778
# 5119   S32T160             32  0.794444  0.447778

# %%
# for i in range(1,33):
#     for ii in range(1,41):
#         os.rename(r'/media/tris/tris_files/github/OoMA-omniscient/data/processed/heatmaps_ind/heatmaps/T'+str(ii)+'S'+str(i)+".png",r'/media/tris/tris_files/github/OoMA-omniscient/data/processed/heatmaps_ind/heatmaps/S'+str(i)+'T'+str(ii)+".png")

# %%
# from PIL import Image

# for i in range (0,1280):
    
#     im = Image.open(r"/media/tris/tris_files/github/OoMA-omniscient/data/processed/heatmaps_ind/heatmaps/"+str(df.file_name[i])+".png")
#     im1=im.crop((0,0,1450,1030))
#     im1.save("/media/tris/tris_files/github/OoMA-omniscient/data/processed/heatmaps_ind/heatmaps_re/"+str(df.file_name[i])+".png")

# %%
df.loc[(df['valence'] >= 0.5) & (df['arousal'] >= 0.5), 'emotion_quad'] = 0  #HVHA
df.loc[(df['valence'] <= 0.5) & (df['arousal'] >= 0.5), 'emotion_quad'] = 1  #LVHA
df.loc[(df['valence'] <= 0.5) & (df['arousal'] <= 0.5), 'emotion_quad'] = 2 #LVLA  
df.loc[(df['valence'] >= 0.5) & (df['arousal'] <= 0.5), 'emotion_quad'] = 3  #HVLA
df.head()
# Out:
#   file_name  subject_label   valence   arousal  emotion_quad
# 0      S1T1              1  0.856667  0.844444           0.0
# 1      S1T2              1  0.856667  0.844444           0.0
# 2      S1T3              1  0.856667  0.844444           0.0
# 3      S1T4              1  0.856667  0.844444           0.0
# 4      S1T5              1  0.900000  0.812222           0.0

# %%
# df.loc[(df['valence'] >= 0.5) & (df['arousal'] >= 0.5), 'emotion_quad'] = 'HVHA'  #HVHA
# df.loc[(df['valence'] <= 0.5) & (df['arousal'] >= 0.5), 'emotion_quad'] = 'LVHA'  #LVHA
# df.loc[(df['valence'] <= 0.5) & (df['arousal'] <= 0.5), 'emotion_quad'] = 'LVLA' #LVLA  
# df.loc[(df['valence'] >= 0.5) & (df['arousal'] <= 0.5), 'emotion_quad'] = 'HVLA'  #HVLA
# df.head()

# %%
df=df.head(n=160)
df=df.reset_index(drop=True); df
# Out:
#     file_name  subject_label   valence   arousal  emotion_quad
# 0        S1T1              1  0.856667  0.844444           0.0
# 1        S1T2              1  0.856667  0.844444           0.0
# 2        S1T3              1  0.856667  0.844444           0.0
# 3        S1T4              1  0.856667  0.844444           0.0
# 4        S1T5              1  0.900000  0.812222           0.0
# ..        ...            ...       ...       ...           ...
# 155    S1T156              1  0.360000  0.686667           1.0
# 156    S1T157              1  0.566667  0.791111           0.0
# 157    S1T158              1  0.566667  0.791111           0.0
# 158    S1T159              1  0.566667  0.791111           0.0
# 159    S1T160              1  0.566667  0.791111           0.0
#
# [160 rows x 5 columns]

# %% [markdown]
# ![GitHub Logo](https://www.researchgate.net/profile/Fadi_Al_Machot/publication/307587787/figure/fig3/AS:572907778318337@1513603266552/Arousal-valence-based-emotional-states.png)

# %%
path=pathlib.Path('/media/tris/tris_files/EEG_datasets/DMD')
path
# Out:
# PosixPath('/media/tris/tris_files/EEG_datasets/DMD')

# %%
df.to_csv(path/'labels_proc_window4.csv', index=False)

# %%
df = pd.read_csv(path/'labels_proc_window4.csv') #load labels
df.tail()
# Out:
#     file_name  subject_label   valence   arousal  emotion_quad
# 155    S1T156              1  0.360000  0.686667           1.0
# 156    S1T157              1  0.566667  0.791111           0.0
# 157    S1T158              1  0.566667  0.791111           0.0
# 158    S1T159              1  0.566667  0.791111           0.0
# 159    S1T160              1  0.566667  0.791111           0.0

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff58c398050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff58c358e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff58c30c750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff58c2bef10>]], dtype=object)

# %% [markdown]
# ## Data loader

# %%
path=pathlib.Path('/media/tris/tris_files/EEG_datasets/DMD')
df = pd.read_csv(path/'labels_proc_window4.csv') #load labels
df.tail()
# Out:
#     file_name  subject_label   valence   arousal  emotion_quad
# 155    S1T156              1  0.360000  0.686667           1.0
# 156    S1T157              1  0.566667  0.791111           0.0
# 157    S1T158              1  0.566667  0.791111           0.0
# 158    S1T159              1  0.566667  0.791111           0.0
# 159    S1T160              1  0.566667  0.791111           0.0

# %%
src = (ImageList.from_csv(path, 'labels_proc_window4.csv', folder='window_4times', suffix='.png')
       .split_by_rand_pct(0.2)
       .label_from_df(cols=['emotion_quad'],label_cls=CategoryList))

# %%
tfms=get_transforms(do_flip=False, flip_vert=False, max_rotate=0,max_zoom=1.1,max_lighting=0.3,p_affine=0)

# %%
data = (src.transform(tfms, size=250)
        .databunch(bs=4).normalize())

# %%
data.show_batch(rows=4, figsize=(12,9))

# %% [markdown]
# ## Setup Network

# %%
learn = cnn_learner(data, models.resnet50, metrics=accuracy)

# %%
learn.summary()
# Out:
# Sequential
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [64, 125, 125]       9,408      False
# ______________________________________________________________________
# BatchNorm2d          [64, 125, 125]       128        True
# ______________________________________________________________________
# ReLU                 [64, 125, 125]       0          False
# ______________________________________________________________________
# MaxPool2d            [64, 63, 63]         0          False
# ______________________________________________________________________
# Conv2d               [64, 63, 63]         4,096      False
# ______________________________________________________________________
# BatchNorm2d          [64, 63, 63]         128        True
# ______________________________________________________________________
# Conv2d               [64, 63, 63]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 63, 63]         128        True
# ______________________________________________________________________
# Conv2d               [256, 63, 63]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 63, 63]        512        True
# ______________________________________________________________________
# ReLU                 [256, 63, 63]        0          False
# ______________________________________________________________________
# Conv2d               [256, 63, 63]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 63, 63]        512        True
# ______________________________________________________________________
# Conv2d               [64, 63, 63]         16,384     False
# ______________________________________________________________________
# BatchNorm2d          [64, 63, 63]         128        True
# ______________________________________________________________________
# Conv2d               [64, 63, 63]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 63, 63]         128        True
# ______________________________________________________________________
# Conv2d               [256, 63, 63]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 63, 63]        512        True
# ______________________________________________________________________
# ReLU                 [256, 63, 63]        0          False
# ______________________________________________________________________
# Conv2d               [64, 63, 63]         16,384     False
# ______________________________________________________________________
# BatchNorm2d          [64, 63, 63]         128        True
# ______________________________________________________________________
# Conv2d               [64, 63, 63]         36,864     False
# ______________________________________________________________________
# BatchNorm2d          [64, 63, 63]         128        True
# ______________________________________________________________________
# Conv2d               [256, 63, 63]        16,384     False
# ______________________________________________________________________
# BatchNorm2d          [256, 63, 63]        512        True
# ______________________________________________________________________
# ReLU                 [256, 63, 63]        0          False
# ______________________________________________________________________
# Conv2d               [128, 63, 63]        32,768     False
# ______________________________________________________________________
# BatchNorm2d          [128, 63, 63]        256        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 32, 32]        0          False
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        131,072    False
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 32, 32]        0          False
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 32, 32]        0          False
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [128, 32, 32]        147,456    False
# ______________________________________________________________________
# BatchNorm2d          [128, 32, 32]        256        True
# ______________________________________________________________________
# Conv2d               [512, 32, 32]        65,536     False
# ______________________________________________________________________
# BatchNorm2d          [512, 32, 32]        1,024      True
# ______________________________________________________________________
# ReLU                 [512, 32, 32]        0          False
# ______________________________________________________________________
# Conv2d               [256, 32, 32]        131,072    False
# ______________________________________________________________________
# BatchNorm2d          [256, 32, 32]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 16, 16]       0          False
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       524,288    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 16, 16]       0          False
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 16, 16]       0          False
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 16, 16]       0          False
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 16, 16]       0          False
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        262,144    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [256, 16, 16]        589,824    False
# ______________________________________________________________________
# BatchNorm2d          [256, 16, 16]        512        True
# ______________________________________________________________________
# Conv2d               [1024, 16, 16]       262,144    False
# ______________________________________________________________________
# BatchNorm2d          [1024, 16, 16]       2,048      True
# ______________________________________________________________________
# ReLU                 [1024, 16, 16]       0          False
# ______________________________________________________________________
# Conv2d               [512, 16, 16]        524,288    False
# ______________________________________________________________________
# BatchNorm2d          [512, 16, 16]        1,024      True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# Conv2d               [2048, 8, 8]         1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 8, 8]         4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [2048, 8, 8]         2,097,152  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 8, 8]         4,096      True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# Conv2d               [2048, 8, 8]         1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 8, 8]         4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 8, 8]         0          False
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# Conv2d               [512, 8, 8]          2,359,296  False
# ______________________________________________________________________
# BatchNorm2d          [512, 8, 8]          1,024      True
# ______________________________________________________________________
# Conv2d               [2048, 8, 8]         1,048,576  False
# ______________________________________________________________________
# BatchNorm2d          [2048, 8, 8]         4,096      True
# ______________________________________________________________________
# ReLU                 [2048, 8, 8]         0          False
# ______________________________________________________________________
# AdaptiveAvgPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [2048, 1, 1]         0          False
# ______________________________________________________________________
# Flatten              [4096]               0          False
# ______________________________________________________________________
# BatchNorm1d          [4096]               8,192      True
# ______________________________________________________________________
# Dropout              [4096]               0          False
# ______________________________________________________________________
# Linear               [512]                2,097,664  True
# ______________________________________________________________________
# ReLU                 [512]                0          False
# ______________________________________________________________________
# BatchNorm1d          [512]                1,024      True
# ______________________________________________________________________
# Dropout              [512]                0          False
# ______________________________________________________________________
# Linear               [4]                  2,052      True
# ______________________________________________________________________
#
# Total params: 25,616,964
# Total trainable params: 2,162,052
# Total non-trainable params: 23,454,912
# Optimized with 'torch.optim.adam.Adam', betas=(0.9, 0.99)
# Using true weight decay as discussed in https://www.fast.ai/2018/07/02/adam-weight-decay/
# Loss function : FlattenedLoss
# ======================================================================
# Callbacks functions applied

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [2/4 00:04<00:04]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.396971</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.370697</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20' class='' max='32', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       62.50% [20/32 00:01<00:00 4.9935]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ## Train last layers

# %%
lr = 3e-3
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.849079</td>
#       <td>2.042932</td>
#       <td>0.375000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.862087</td>
#       <td>2.197865</td>
#       <td>0.312500</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.562391</td>
#       <td>1.055046</td>
#       <td>0.625000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.263966</td>
#       <td>1.135585</td>
#       <td>0.562500</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.980264</td>
#       <td>1.106090</td>
#       <td>0.593750</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_metrics()

# %%
learn.recorder.plot_losses()

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.644001</td>
#       <td>0.937815</td>
#       <td>0.656250</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.957338</td>
#       <td>1.438220</td>
#       <td>0.500000</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.969616</td>
#       <td>1.329464</td>
#       <td>0.593750</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.863488</td>
#       <td>1.017700</td>
#       <td>0.593750</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.739587</td>
#       <td>1.115490</td>
#       <td>0.562500</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Train the whole network

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='4', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [2/4 00:05<00:05]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.685884</td>
#       <td>#na#</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.209835</td>
#       <td>#na#</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='17' class='' max='32', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       53.12% [17/32 00:01<00:01 2.7703]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr = 1e-4
learn.fit_one_cycle(10, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.575347</td>
#       <td>1.073577</td>
#       <td>0.562500</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.600491</td>
#       <td>1.064673</td>
#       <td>0.593750</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.565282</td>
#       <td>1.070127</td>
#       <td>0.531250</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.549393</td>
#       <td>1.110600</td>
#       <td>0.531250</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.557202</td>
#       <td>1.055303</td>
#       <td>0.531250</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.553128</td>
#       <td>1.194241</td>
#       <td>0.500000</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.572147</td>
#       <td>1.254992</td>
#       <td>0.437500</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.452790</td>
#       <td>1.144854</td>
#       <td>0.437500</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.570128</td>
#       <td>1.074924</td>
#       <td>0.437500</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.548478</td>
#       <td>1.052840</td>
#       <td>0.468750</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Interpret and Results

# %%
learn.show_results()

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)

# %%
interp.plot_confusion_matrix(figsize=(10,10))

# %%
interp.plot_top_losses(4)
