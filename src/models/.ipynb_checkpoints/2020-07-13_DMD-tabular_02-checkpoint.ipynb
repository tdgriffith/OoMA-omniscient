# %% [markdown]
# # Tabular ANN for Exploration of DEAP Dataset
# Fingerprinting with DMD modes has worked really well. What about in tabular format?

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
# %%javascript
# utils.load_extension('collapsible_headings/main')
# utils.load_extension('hide_input/main')
# utils.load_extension('execute_time/ExecuteTime')
# utils.load_extension('code_prettify/code_prettify')
# utils.load_extension('scroll_down/main')
# utils.load_extension('jupyter-js-widgets/extension')

# %%
from fastai.tabular import *

# %%
PATH = "/media/tris/tris_files/EEG_datasets/DMD/tabular"

# %%
df_raw = pd.read_csv('/media/tris/tris_files/EEG_datasets/DMD/tabular/dmd_deap_100modes_trials2.csv')
df_raw
# Out:
#       Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 0           1      1         -0.233814         -0.969863          1.700171
# 1           1      2         -0.993878         -0.016554          1.770978
# 2           1      3          0.583622          0.629451         -0.735135
# 3           1      4         -0.012731          1.519274          0.444013
# 4           1      5         -0.142715          0.161444          0.754088
# ...       ...    ...               ...               ...               ...
# 1275       32     36          0.402701          0.698310         -0.014948
# 1276       32     37          0.335937          0.687189         -0.209331
# 1277       32     38         -0.822827         -0.549796         -1.011708
# 1278       32     39         -0.794072          0.698358         -0.938047
# 1279       32     40          0.195646         -0.556881          0.311691
#
#       Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 0             0.720502          0.177535         -0.046507          1.072643
# 1            -0.831954          0.097792         -0.621644          0.577972
# 2            -1.448728         -0.377700          0.173252         -0.779868
# 3             0.687163          1.043211         -0.787845          0.113916
# 4             1.518170         -1.628491          0.075984         -0.649745
# ...                ...               ...               ...               ...
# 1275          0.628291          0.727424          0.667963          0.460412
# 1276          0.414581         -0.870939          0.714841          0.354585
# 1277         -1.082957          0.996392         -0.766131         -0.839676
# 1278         -5.002665         -0.472358         -0.935446         -1.867492
# 1279         -0.673721         -0.153034         -0.289739         -0.227752
#
#       Real_Comp8_Mode1  ...    zeta41    zeta42    zeta43    zeta44    zeta45  \
# 0            -0.120264  ...  0.166065  0.280451  0.114258  0.109801  0.173911
# 1             1.328111  ...  0.171891  0.106523  0.133571  0.194492  0.244793
# 2            -0.060316  ...  0.123279  0.182684  0.162244  0.228377  0.186304
# 3             1.043668  ...  0.190128  0.181409  0.141337  0.111817  0.194721
# 4            -0.974299  ...  0.123980  0.180104  0.127765  0.191395  0.117568
# ...                ...  ...       ...       ...       ...       ...       ...
# 1275          0.362815  ...  0.096206  0.138511  0.115592  0.116468  0.176696
# 1276         -0.404037  ...  0.114424  0.170725  0.240344  0.121923  0.173749
# 1277          0.825158  ...  0.311907  0.115688  0.145812  0.138956  0.196466
# 1278         -1.125174  ...  0.137895  0.114168  0.102125  0.262071  0.206464
# 1279          0.411163  ...  0.133803  0.103198  0.109458  0.219574  0.171895
#
#         zeta46    zeta47    zeta48    zeta49    zeta50
# 0     0.157928  0.191574  0.137560  0.177926  0.207574
# 1     0.159942  0.161214  0.197641  0.201198  0.182560
# 2     0.241429  0.172226  0.168193  0.269286  0.213699
# 3     0.147402  0.199616  0.229632  0.167897  0.203443
# 4     0.113275  0.221683  0.139448  0.163605  0.184403
# ...        ...       ...       ...       ...       ...
# 1275  0.161931  0.155996  0.202108  0.212839  0.160285
# 1276  0.115140  0.189734  0.141533  0.227506  0.223675
# 1277  0.161459  0.140366  0.235394  0.206119  0.178013
# 1278  0.166950  0.186174  0.153145  0.188538  0.212354
# 1279  0.147832  0.154817  0.166979  0.184399  0.183478
#
# [1280 rows x 3302 columns]

# %%
df_raw.iloc[[40],:]
# Out:
#     Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 40        2      1          2.103902         -1.555795          -4.76561
#
#     Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 40          1.745002         -0.038243         -1.276566         -0.490062
#
#     Real_Comp8_Mode1  ...    zeta41    zeta42    zeta43    zeta44    zeta45  \
# 40         -2.453432  ...  0.167794  0.265412  0.061066  0.129821  0.096107
#
#       zeta46    zeta47    zeta48  zeta49    zeta50
# 40  0.267482  0.119305  0.125482  0.1402  0.182562
#
# [1 rows x 3302 columns]

# %%
os.makedirs('tmp', exist_ok=True)
df_raw.to_feather('tmp/eeg-raw')

# %%
import pandas as pd
df_raw = pd.read_feather('tmp/eeg-raw') #lol raw sashimis and sushis
df_raw.head()
# Out:
#    Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 0        1      1         -0.233814         -0.969863          1.700171
# 1        1      2         -0.993878         -0.016554          1.770978
# 2        1      3          0.583622          0.629451         -0.735135
# 3        1      4         -0.012731          1.519274          0.444013
# 4        1      5         -0.142715          0.161444          0.754088
#
#    Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 0          0.720502          0.177535         -0.046507          1.072643
# 1         -0.831954          0.097792         -0.621644          0.577972
# 2         -1.448728         -0.377700          0.173252         -0.779868
# 3          0.687163          1.043211         -0.787845          0.113916
# 4          1.518170         -1.628491          0.075984         -0.649745
#
#    Real_Comp8_Mode1  ...    zeta41    zeta42    zeta43    zeta44    zeta45  \
# 0         -0.120264  ...  0.166065  0.280451  0.114258  0.109801  0.173911
# 1          1.328111  ...  0.171891  0.106523  0.133571  0.194492  0.244793
# 2         -0.060316  ...  0.123279  0.182684  0.162244  0.228377  0.186304
# 3          1.043668  ...  0.190128  0.181409  0.141337  0.111817  0.194721
# 4         -0.974299  ...  0.123980  0.180104  0.127765  0.191395  0.117568
#
#      zeta46    zeta47    zeta48    zeta49    zeta50
# 0  0.157928  0.191574  0.137560  0.177926  0.207574
# 1  0.159942  0.161214  0.197641  0.201198  0.182560
# 2  0.241429  0.172226  0.168193  0.269286  0.213699
# 3  0.147402  0.199616  0.229632  0.167897  0.203443
# 4  0.113275  0.221683  0.139448  0.163605  0.184403
#
# [5 rows x 3302 columns]

# %%
df_raw.iloc[[500],:]
# Out:
#      Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 500       13     21         -0.636539          1.753147         -2.544426
#
#      Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 500         -2.368353         -0.251682         -1.778326          0.345435
#
#      Real_Comp8_Mode1  ...    zeta41    zeta42    zeta43    zeta44    zeta45  \
# 500          0.820399  ...  0.267574  0.313899  0.172418  0.129389  0.193406
#
#        zeta46    zeta47    zeta48    zeta49    zeta50
# 500  0.161502  0.171978  0.207269  0.203898  0.220929
#
# [1 rows x 3302 columns]

# %%
path = '/media/tris/tris_files/EEG_datasets/DEAP_data_preprocessed_python/s01.dat'
df_read = pickle.load(open(path, 'rb'), encoding='latin1')
labels=df_read['labels']
df_tmp = pd.DataFrame(labels, columns=['valence','arousal','dominance','liking'])
df=df_tmp
for n in range (2,10):
    path = '/media/tris/tris_files/EEG_datasets/DEAP_data_preprocessed_python/s0'+str(n)+'.dat'
    df_read = pickle.load(open(path, 'rb'), encoding='latin1')
    labels=df_read['labels']
    df_tmp = pd.DataFrame(labels, columns=['valence','arousal','dominance','liking'])
    df=df.append(df_tmp, ignore_index=True)
for n in range (10,33):
    path = '/media/tris/tris_files/EEG_datasets/DEAP_data_preprocessed_python/s'+str(n)+'.dat'
    df_read = pickle.load(open(path, 'rb'), encoding='latin1')
    labels=df_read['labels']
    df_tmp = pd.DataFrame(labels, columns=['valence','arousal','dominance','liking'])
    df=df.append(df_tmp, ignore_index=True)

# %%
df=df.div(9) #normalize

# %%
df.loc[(df['valence'] >= 0.5) & (df['arousal'] >= 0.5), 'emotion_quad'] = 'HVHA'
df.loc[(df['valence'] <= 0.5) & (df['arousal'] >= 0.5), 'emotion_quad'] = 'LVHA'
df.loc[(df['valence'] <= 0.5) & (df['arousal'] <= 0.5), 'emotion_quad'] = 'LVLA'  
df.loc[(df['valence'] >= 0.5) & (df['arousal'] <= 0.5), 'emotion_quad'] = 'HVLA'
df.tail()
# Out:
#        valence   arousal  dominance    liking emotion_quad
# 1275  0.434444  0.773333   0.646667  0.346667         LVHA
# 1276  0.312222  0.681111   0.673333  0.115556         LVHA
# 1277  0.338889  0.778889   0.566667  0.122222         LVHA
# 1278  0.443333  0.796667   0.538889  0.111111         LVHA
# 1279  0.794444  0.447778   1.000000  0.208889         HVLA

# %%
emotion_quad = df['emotion_quad']
df_learn = df_raw.join(emotion_quad)
df_learn.head()
# Out:
#    Subject  Trial  Real_Comp1_Mode1  Real_Comp2_Mode1  Real_Comp3_Mode1  \
# 0        1      1         -0.233814         -0.969863          1.700171
# 1        1      2         -0.993878         -0.016554          1.770978
# 2        1      3          0.583622          0.629451         -0.735135
# 3        1      4         -0.012731          1.519274          0.444013
# 4        1      5         -0.142715          0.161444          0.754088
#
#    Real_Comp4_Mode1  Real_Comp5_Mode1  Real_Comp6_Mode1  Real_Comp7_Mode1  \
# 0          0.720502          0.177535         -0.046507          1.072643
# 1         -0.831954          0.097792         -0.621644          0.577972
# 2         -1.448728         -0.377700          0.173252         -0.779868
# 3          0.687163          1.043211         -0.787845          0.113916
# 4          1.518170         -1.628491          0.075984         -0.649745
#
#    Real_Comp8_Mode1  ...    zeta42    zeta43    zeta44    zeta45    zeta46  \
# 0         -0.120264  ...  0.280451  0.114258  0.109801  0.173911  0.157928
# 1          1.328111  ...  0.106523  0.133571  0.194492  0.244793  0.159942
# 2         -0.060316  ...  0.182684  0.162244  0.228377  0.186304  0.241429
# 3          1.043668  ...  0.181409  0.141337  0.111817  0.194721  0.147402
# 4         -0.974299  ...  0.180104  0.127765  0.191395  0.117568  0.113275
#
#      zeta47    zeta48    zeta49    zeta50  emotion_quad
# 0  0.191574  0.137560  0.177926  0.207574          HVHA
# 1  0.161214  0.197641  0.201198  0.182560          HVHA
# 2  0.172226  0.168193  0.269286  0.213699          HVHA
# 3  0.199616  0.229632  0.167897  0.203443          HVHA
# 4  0.221683  0.139448  0.163605  0.184403          HVLA
#
# [5 rows x 3303 columns]

# %%
fig, axs = plt.subplots(1, 4, figsize=(15, 5))
axs[0].hist(df_learn.Real_Comp1_Mode1)
axs[0].set_title('Real_Comp1_Mode1')
axs[1].hist(df_learn.fn3)
axs[1].set_title('fn3')
axs[2].hist(df_learn.Imag_Comp1_Mode1)
axs[2].set_title('Imag_Comp1_Mode1')
axs[3].hist(df_learn.zeta49)
axs[3].set_title('zeta49')
axs[3].hist(df_learn.emotion_quad)
axs[3].set_title('label')
# Out:
# Text(0.5, 1.0, 'label')

# %%
valid_idx=np.random.randint(low=0, high=len(df_learn), size=256)

# %%
dep_var= 'emotion_quad'

# %%
path = "/media/tris/tris_files/EEG_datasets/DMD/tabular"

# %%
data = TabularDataBunch.from_df(path, df_learn, dep_var, valid_idx=valid_idx)

# %%
data.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Imag_Comp29_Mode29</th>
#       <th>Real_Comp19_Mode22</th>
#       <th>Real_Comp7_Mode23</th>
#       <th>Real_Comp5_Mode19</th>
#       <th>Real_Comp23_Mode41</th>
#       <th>Subject</th>
#       <th>Imag_Comp14_Mode3</th>
#       <th>Real_Comp2_Mode37</th>
#       <th>Imag_Comp7_Mode27</th>
#       <th>Real_Comp26_Mode31</th>
#       <th>Real_Comp28_Mode48</th>
#       <th>Imag_Comp32_Mode22</th>
#       <th>Imag_Comp27_Mode33</th>
#       <th>Real_Comp22_Mode14</th>
#       <th>Real_Comp6_Mode23</th>
#       <th>Real_Comp8_Mode37</th>
#       <th>Imag_Comp25_Mode6</th>
#       <th>Imag_Comp5_Mode35</th>
#       <th>Real_Comp4_Mode16</th>
#       <th>Imag_Comp32_Mode34</th>
#       <th>Imag_Comp26_Mode13</th>
#       <th>Real_Comp12_Mode42</th>
#       <th>Imag_Comp30_Mode45</th>
#       <th>Imag_Comp21_Mode21</th>
#       <th>Real_Comp20_Mode41</th>
#       <th>Real_Comp2_Mode3</th>
#       <th>Real_Comp5_Mode48</th>
#       <th>Imag_Comp32_Mode43</th>
#       <th>fn4</th>
#       <th>Real_Comp6_Mode37</th>
#       <th>Imag_Comp23_Mode28</th>
#       <th>Imag_Comp7_Mode38</th>
#       <th>Imag_Comp14_Mode45</th>
#       <th>Real_Comp21_Mode30</th>
#       <th>Imag_Comp22_Mode22</th>
#       <th>Real_Comp1_Mode35</th>
#       <th>Imag_Comp6_Mode21</th>
#       <th>Real_Comp27_Mode10</th>
#       <th>zeta33</th>
#       <th>Real_Comp1_Mode24</th>
#       <th>Imag_Comp13_Mode40</th>
#       <th>Real_Comp19_Mode26</th>
#       <th>Real_Comp29_Mode15</th>
#       <th>Real_Comp18_Mode48</th>
#       <th>Imag_Comp21_Mode15</th>
#       <th>Real_Comp31_Mode19</th>
#       <th>Real_Comp18_Mode10</th>
#       <th>Imag_Comp1_Mode10</th>
#       <th>Imag_Comp24_Mode35</th>
#       <th>Imag_Comp10_Mode2</th>
#       <th>Real_Comp31_Mode42</th>
#       <th>Real_Comp24_Mode6</th>
#       <th>Real_Comp18_Mode32</th>
#       <th>Imag_Comp1_Mode38</th>
#       <th>Real_Comp1_Mode30</th>
#       <th>Imag_Comp4_Mode27</th>
#       <th>Imag_Comp23_Mode18</th>
#       <th>Real_Comp22_Mode46</th>
#       <th>Real_Comp28_Mode45</th>
#       <th>Imag_Comp1_Mode48</th>
#       <th>Imag_Comp30_Mode30</th>
#       <th>Imag_Comp17_Mode14</th>
#       <th>Real_Comp16_Mode24</th>
#       <th>Imag_Comp20_Mode14</th>
#       <th>Imag_Comp1_Mode37</th>
#       <th>Imag_Comp25_Mode31</th>
#       <th>Real_Comp16_Mode49</th>
#       <th>Real_Comp11_Mode28</th>
#       <th>Real_Comp26_Mode42</th>
#       <th>Imag_Comp25_Mode13</th>
#       <th>Real_Comp13_Mode26</th>
#       <th>Real_Comp32_Mode18</th>
#       <th>Real_Comp31_Mode41</th>
#       <th>Real_Comp23_Mode42</th>
#       <th>Imag_Comp22_Mode4</th>
#       <th>Imag_Comp29_Mode7</th>
#       <th>Imag_Comp30_Mode10</th>
#       <th>Real_Comp32_Mode16</th>
#       <th>Real_Comp2_Mode41</th>
#       <th>Real_Comp29_Mode36</th>
#       <th>Imag_Comp18_Mode26</th>
#       <th>Imag_Comp9_Mode38</th>
#       <th>Imag_Comp18_Mode18</th>
#       <th>Imag_Comp20_Mode20</th>
#       <th>Imag_Comp16_Mode1</th>
#       <th>Imag_Comp30_Mode46</th>
#       <th>Imag_Comp7_Mode45</th>
#       <th>Imag_Comp21_Mode36</th>
#       <th>Imag_Comp9_Mode50</th>
#       <th>Real_Comp21_Mode15</th>
#       <th>Imag_Comp23_Mode9</th>
#       <th>Real_Comp20_Mode39</th>
#       <th>Real_Comp15_Mode11</th>
#       <th>Imag_Comp1_Mode20</th>
#       <th>Imag_Comp27_Mode21</th>
#       <th>Imag_Comp28_Mode36</th>
#       <th>Imag_Comp30_Mode41</th>
#       <th>Imag_Comp25_Mode43</th>
#       <th>Imag_Comp29_Mode15</th>
#       <th>Real_Comp11_Mode30</th>
#       <th>Real_Comp5_Mode31</th>
#       <th>Imag_Comp15_Mode34</th>
#       <th>Imag_Comp20_Mode1</th>
#       <th>Imag_Comp14_Mode47</th>
#       <th>Real_Comp20_Mode40</th>
#       <th>Real_Comp11_Mode13</th>
#       <th>Imag_Comp7_Mode14</th>
#       <th>Real_Comp22_Mode7</th>
#       <th>Real_Comp26_Mode24</th>
#       <th>Real_Comp18_Mode24</th>
#       <th>Imag_Comp28_Mode27</th>
#       <th>Real_Comp9_Mode28</th>
#       <th>Imag_Comp29_Mode13</th>
#       <th>Real_Comp19_Mode2</th>
#       <th>Real_Comp15_Mode32</th>
#       <th>Real_Comp23_Mode3</th>
#       <th>Imag_Comp16_Mode10</th>
#       <th>Real_Comp3_Mode36</th>
#       <th>Real_Comp6_Mode11</th>
#       <th>Real_Comp21_Mode13</th>
#       <th>Imag_Comp32_Mode18</th>
#       <th>Imag_Comp13_Mode19</th>
#       <th>Real_Comp30_Mode27</th>
#       <th>Real_Comp12_Mode44</th>
#       <th>Real_Comp29_Mode14</th>
#       <th>Imag_Comp5_Mode4</th>
#       <th>Imag_Comp25_Mode20</th>
#       <th>Imag_Comp5_Mode28</th>
#       <th>Imag_Comp28_Mode40</th>
#       <th>Real_Comp20_Mode42</th>
#       <th>Real_Comp26_Mode12</th>
#       <th>Real_Comp10_Mode22</th>
#       <th>Imag_Comp5_Mode21</th>
#       <th>Real_Comp19_Mode15</th>
#       <th>Imag_Comp22_Mode21</th>
#       <th>Real_Comp23_Mode37</th>
#       <th>Imag_Comp17_Mode1</th>
#       <th>Imag_Comp27_Mode26</th>
#       <th>Real_Comp20_Mode11</th>
#       <th>Real_Comp5_Mode14</th>
#       <th>Real_Comp11_Mode42</th>
#       <th>Real_Comp17_Mode42</th>
#       <th>Real_Comp2_Mode48</th>
#       <th>Imag_Comp6_Mode1</th>
#       <th>Real_Comp3_Mode12</th>
#       <th>Real_Comp22_Mode44</th>
#       <th>Real_Comp7_Mode29</th>
#       <th>Imag_Comp4_Mode9</th>
#       <th>Real_Comp23_Mode22</th>
#       <th>Imag_Comp14_Mode18</th>
#       <th>Real_Comp7_Mode37</th>
#       <th>Imag_Comp29_Mode46</th>
#       <th>Imag_Comp21_Mode4</th>
#       <th>Imag_Comp6_Mode49</th>
#       <th>Imag_Comp20_Mode45</th>
#       <th>Real_Comp5_Mode50</th>
#       <th>Real_Comp6_Mode3</th>
#       <th>Imag_Comp17_Mode36</th>
#       <th>Real_Comp8_Mode32</th>
#       <th>Imag_Comp11_Mode27</th>
#       <th>Imag_Comp32_Mode15</th>
#       <th>Real_Comp18_Mode7</th>
#       <th>Imag_Comp20_Mode44</th>
#       <th>Real_Comp11_Mode36</th>
#       <th>Imag_Comp21_Mode28</th>
#       <th>Imag_Comp1_Mode49</th>
#       <th>Real_Comp19_Mode46</th>
#       <th>Real_Comp25_Mode15</th>
#       <th>Imag_Comp3_Mode13</th>
#       <th>Imag_Comp16_Mode39</th>
#       <th>Real_Comp31_Mode14</th>
#       <th>Real_Comp8_Mode36</th>
#       <th>Real_Comp15_Mode34</th>
#       <th>Real_Comp10_Mode48</th>
#       <th>Imag_Comp2_Mode27</th>
#       <th>Imag_Comp10_Mode7</th>
#       <th>Real_Comp23_Mode10</th>
#       <th>Real_Comp30_Mode30</th>
#       <th>Real_Comp19_Mode43</th>
#       <th>Real_Comp12_Mode48</th>
#       <th>Imag_Comp32_Mode29</th>
#       <th>Imag_Comp15_Mode50</th>
#       <th>Imag_Comp22_Mode34</th>
#       <th>Real_Comp1_Mode20</th>
#       <th>Real_Comp11_Mode2</th>
#       <th>Imag_Comp8_Mode47</th>
#       <th>Imag_Comp3_Mode49</th>
#       <th>Real_Comp25_Mode37</th>
#       <th>Imag_Comp12_Mode40</th>
#       <th>Imag_Comp3_Mode21</th>
#       <th>Real_Comp24_Mode47</th>
#       <th>Imag_Comp26_Mode50</th>
#       <th>Imag_Comp9_Mode23</th>
#       <th>Imag_Comp2_Mode28</th>
#       <th>Imag_Comp19_Mode32</th>
#       <th>Real_Comp8_Mode48</th>
#       <th>Imag_Comp31_Mode13</th>
#       <th>Imag_Comp12_Mode50</th>
#       <th>zeta10</th>
#       <th>Imag_Comp9_Mode21</th>
#       <th>Real_Comp15_Mode31</th>
#       <th>Imag_Comp28_Mode24</th>
#       <th>Real_Comp16_Mode22</th>
#       <th>Real_Comp7_Mode1</th>
#       <th>Real_Comp23_Mode33</th>
#       <th>Imag_Comp4_Mode21</th>
#       <th>Imag_Comp17_Mode10</th>
#       <th>Imag_Comp20_Mode41</th>
#       <th>Real_Comp23_Mode28</th>
#       <th>Imag_Comp29_Mode22</th>
#       <th>Real_Comp21_Mode5</th>
#       <th>Imag_Comp19_Mode11</th>
#       <th>Real_Comp22_Mode39</th>
#       <th>Imag_Comp9_Mode41</th>
#       <th>Imag_Comp25_Mode47</th>
#       <th>Imag_Comp13_Mode10</th>
#       <th>Imag_Comp24_Mode27</th>
#       <th>Real_Comp10_Mode46</th>
#       <th>Real_Comp14_Mode46</th>
#       <th>Imag_Comp21_Mode24</th>
#       <th>Real_Comp32_Mode29</th>
#       <th>Real_Comp4_Mode40</th>
#       <th>Imag_Comp13_Mode26</th>
#       <th>Imag_Comp22_Mode44</th>
#       <th>Imag_Comp27_Mode49</th>
#       <th>Imag_Comp9_Mode31</th>
#       <th>Real_Comp26_Mode23</th>
#       <th>Real_Comp14_Mode21</th>
#       <th>Imag_Comp23_Mode37</th>
#       <th>Real_Comp22_Mode8</th>
#       <th>Imag_Comp21_Mode14</th>
#       <th>Imag_Comp10_Mode29</th>
#       <th>Real_Comp15_Mode43</th>
#       <th>Real_Comp8_Mode26</th>
#       <th>Real_Comp2_Mode9</th>
#       <th>Real_Comp1_Mode49</th>
#       <th>Real_Comp17_Mode31</th>

# %%
# max_log_y = np.log(np.max(df_raw['subject'])*1.2)
# y_range = torch.tensor([0, max_log_y])

# %%
# learn = tabular_learner(data, layers=[2000,500], ps=[0.001,0.01], emb_drop=0.04, metrics=accuracy, emb_szs={'emotion_quad': 4})
learn = tabular_learner(data, layers=[100,10], ps=[0.001,0.01], emb_drop=0.04, metrics=accuracy)

# %%
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList()
#   (emb_drop): Dropout(p=0.04, inplace=False)
#   (bn_cont): BatchNorm1d(3302, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=3302, out_features=100, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.001, inplace=False)
#     (4): Linear(in_features=100, out_features=10, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.01, inplace=False)
#     (8): Linear(in_features=10, out_features=4, bias=True)
#   )
# )

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       85.71% [6/7 00:01<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.542162</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.535308</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.488980</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.308597</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.177490</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.963152</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='16', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.50% [2/16 00:00<00:00 3.6880]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, 1e-2, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.511453</td>
#       <td>1.720474</td>
#       <td>0.230469</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.231571</td>
#       <td>1.451681</td>
#       <td>0.339844</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.958809</td>
#       <td>1.639324</td>
#       <td>0.351562</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.704827</td>
#       <td>1.693411</td>
#       <td>0.339844</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.535124</td>
#       <td>1.713761</td>
#       <td>0.347656</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       71.43% [5/7 00:01<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.198265</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.195997</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.195447</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.181177</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.501199</td>
#       <td>#na#</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='16', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       31.25% [5/16 00:00<00:00 0.6249]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(25, 1e-2, wd=0.5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.185954</td>
#       <td>1.720258</td>
#       <td>0.347656</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.175048</td>
#       <td>1.740738</td>
#       <td>0.351562</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.147041</td>
#       <td>1.775997</td>
#       <td>0.367188</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.119206</td>
#       <td>1.834621</td>
#       <td>0.367188</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.095994</td>
#       <td>1.908841</td>
#       <td>0.339844</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.082826</td>
#       <td>2.027338</td>
#       <td>0.347656</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.151760</td>
#       <td>2.434980</td>
#       <td>0.351562</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.343323</td>
#       <td>1.894224</td>
#       <td>0.316406</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.342356</td>
#       <td>1.672911</td>
#       <td>0.339844</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.278264</td>
#       <td>1.993834</td>
#       <td>0.382812</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.213902</td>
#       <td>1.786162</td>
#       <td>0.343750</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.163968</td>
#       <td>1.793600</td>
#       <td>0.382812</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.126023</td>
#       <td>1.795204</td>
#       <td>0.390625</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.098115</td>
#       <td>1.800218</td>
#       <td>0.371094</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.077587</td>
#       <td>1.832657</td>
#       <td>0.398438</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.062153</td>
#       <td>1.823732</td>
#       <td>0.371094</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.050634</td>
#       <td>1.862005</td>
#       <td>0.394531</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.042381</td>
#       <td>1.852964</td>
#       <td>0.378906</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.035947</td>
#       <td>1.898633</td>
#       <td>0.378906</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.030995</td>
#       <td>1.888358</td>
#       <td>0.375000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.027033</td>
#       <td>1.933460</td>
#       <td>0.371094</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.024161</td>
#       <td>1.947568</td>
#       <td>0.371094</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.022526</td>
#       <td>1.955144</td>
#       <td>0.371094</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.020991</td>
#       <td>1.976093</td>
#       <td>0.378906</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.019770</td>
#       <td>1.975022</td>
#       <td>0.367188</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Imag_Comp29_Mode29</th>
#       <th>Real_Comp19_Mode22</th>
#       <th>Real_Comp7_Mode23</th>
#       <th>Real_Comp5_Mode19</th>
#       <th>Real_Comp23_Mode41</th>
#       <th>Subject</th>
#       <th>Imag_Comp14_Mode3</th>
#       <th>Real_Comp2_Mode37</th>
#       <th>Imag_Comp7_Mode27</th>
#       <th>Real_Comp26_Mode31</th>
#       <th>Real_Comp28_Mode48</th>
#       <th>Imag_Comp32_Mode22</th>
#       <th>Imag_Comp27_Mode33</th>
#       <th>Real_Comp22_Mode14</th>
#       <th>Real_Comp6_Mode23</th>
#       <th>Real_Comp8_Mode37</th>
#       <th>Imag_Comp25_Mode6</th>
#       <th>Imag_Comp5_Mode35</th>
#       <th>Real_Comp4_Mode16</th>
#       <th>Imag_Comp32_Mode34</th>
#       <th>Imag_Comp26_Mode13</th>
#       <th>Real_Comp12_Mode42</th>
#       <th>Imag_Comp30_Mode45</th>
#       <th>Imag_Comp21_Mode21</th>
#       <th>Real_Comp20_Mode41</th>
#       <th>Real_Comp2_Mode3</th>
#       <th>Real_Comp5_Mode48</th>
#       <th>Imag_Comp32_Mode43</th>
#       <th>fn4</th>
#       <th>Real_Comp6_Mode37</th>
#       <th>Imag_Comp23_Mode28</th>
#       <th>Imag_Comp7_Mode38</th>
#       <th>Imag_Comp14_Mode45</th>
#       <th>Real_Comp21_Mode30</th>
#       <th>Imag_Comp22_Mode22</th>
#       <th>Real_Comp1_Mode35</th>
#       <th>Imag_Comp6_Mode21</th>
#       <th>Real_Comp27_Mode10</th>
#       <th>zeta33</th>
#       <th>Real_Comp1_Mode24</th>
#       <th>Imag_Comp13_Mode40</th>
#       <th>Real_Comp19_Mode26</th>
#       <th>Real_Comp29_Mode15</th>
#       <th>Real_Comp18_Mode48</th>
#       <th>Imag_Comp21_Mode15</th>
#       <th>Real_Comp31_Mode19</th>
#       <th>Real_Comp18_Mode10</th>
#       <th>Imag_Comp1_Mode10</th>
#       <th>Imag_Comp24_Mode35</th>
#       <th>Imag_Comp10_Mode2</th>
#       <th>Real_Comp31_Mode42</th>
#       <th>Real_Comp24_Mode6</th>
#       <th>Real_Comp18_Mode32</th>
#       <th>Imag_Comp1_Mode38</th>
#       <th>Real_Comp1_Mode30</th>
#       <th>Imag_Comp4_Mode27</th>
#       <th>Imag_Comp23_Mode18</th>
#       <th>Real_Comp22_Mode46</th>
#       <th>Real_Comp28_Mode45</th>
#       <th>Imag_Comp1_Mode48</th>
#       <th>Imag_Comp30_Mode30</th>
#       <th>Imag_Comp17_Mode14</th>
#       <th>Real_Comp16_Mode24</th>
#       <th>Imag_Comp20_Mode14</th>
#       <th>Imag_Comp1_Mode37</th>
#       <th>Imag_Comp25_Mode31</th>
#       <th>Real_Comp16_Mode49</th>
#       <th>Real_Comp11_Mode28</th>
#       <th>Real_Comp26_Mode42</th>
#       <th>Imag_Comp25_Mode13</th>
#       <th>Real_Comp13_Mode26</th>
#       <th>Real_Comp32_Mode18</th>
#       <th>Real_Comp31_Mode41</th>
#       <th>Real_Comp23_Mode42</th>
#       <th>Imag_Comp22_Mode4</th>
#       <th>Imag_Comp29_Mode7</th>
#       <th>Imag_Comp30_Mode10</th>
#       <th>Real_Comp32_Mode16</th>
#       <th>Real_Comp2_Mode41</th>
#       <th>Real_Comp29_Mode36</th>
#       <th>Imag_Comp18_Mode26</th>
#       <th>Imag_Comp9_Mode38</th>
#       <th>Imag_Comp18_Mode18</th>
#       <th>Imag_Comp20_Mode20</th>
#       <th>Imag_Comp16_Mode1</th>
#       <th>Imag_Comp30_Mode46</th>
#       <th>Imag_Comp7_Mode45</th>
#       <th>Imag_Comp21_Mode36</th>
#       <th>Imag_Comp9_Mode50</th>
#       <th>Real_Comp21_Mode15</th>
#       <th>Imag_Comp23_Mode9</th>
#       <th>Real_Comp20_Mode39</th>
#       <th>Real_Comp15_Mode11</th>
#       <th>Imag_Comp1_Mode20</th>
#       <th>Imag_Comp27_Mode21</th>
#       <th>Imag_Comp28_Mode36</th>
#       <th>Imag_Comp30_Mode41</th>
#       <th>Imag_Comp25_Mode43</th>
#       <th>Imag_Comp29_Mode15</th>
#       <th>Real_Comp11_Mode30</th>
#       <th>Real_Comp5_Mode31</th>
#       <th>Imag_Comp15_Mode34</th>
#       <th>Imag_Comp20_Mode1</th>
#       <th>Imag_Comp14_Mode47</th>
#       <th>Real_Comp20_Mode40</th>
#       <th>Real_Comp11_Mode13</th>
#       <th>Imag_Comp7_Mode14</th>
#       <th>Real_Comp22_Mode7</th>
#       <th>Real_Comp26_Mode24</th>
#       <th>Real_Comp18_Mode24</th>
#       <th>Imag_Comp28_Mode27</th>
#       <th>Real_Comp9_Mode28</th>
#       <th>Imag_Comp29_Mode13</th>
#       <th>Real_Comp19_Mode2</th>
#       <th>Real_Comp15_Mode32</th>
#       <th>Real_Comp23_Mode3</th>
#       <th>Imag_Comp16_Mode10</th>
#       <th>Real_Comp3_Mode36</th>
#       <th>Real_Comp6_Mode11</th>
#       <th>Real_Comp21_Mode13</th>
#       <th>Imag_Comp32_Mode18</th>
#       <th>Imag_Comp13_Mode19</th>
#       <th>Real_Comp30_Mode27</th>
#       <th>Real_Comp12_Mode44</th>
#       <th>Real_Comp29_Mode14</th>
#       <th>Imag_Comp5_Mode4</th>
#       <th>Imag_Comp25_Mode20</th>
#       <th>Imag_Comp5_Mode28</th>
#       <th>Imag_Comp28_Mode40</th>
#       <th>Real_Comp20_Mode42</th>
#       <th>Real_Comp26_Mode12</th>
#       <th>Real_Comp10_Mode22</th>
#       <th>Imag_Comp5_Mode21</th>
#       <th>Real_Comp19_Mode15</th>
#       <th>Imag_Comp22_Mode21</th>
#       <th>Real_Comp23_Mode37</th>
#       <th>Imag_Comp17_Mode1</th>
#       <th>Imag_Comp27_Mode26</th>
#       <th>Real_Comp20_Mode11</th>
#       <th>Real_Comp5_Mode14</th>
#       <th>Real_Comp11_Mode42</th>
#       <th>Real_Comp17_Mode42</th>
#       <th>Real_Comp2_Mode48</th>
#       <th>Imag_Comp6_Mode1</th>
#       <th>Real_Comp3_Mode12</th>
#       <th>Real_Comp22_Mode44</th>
#       <th>Real_Comp7_Mode29</th>
#       <th>Imag_Comp4_Mode9</th>
#       <th>Real_Comp23_Mode22</th>
#       <th>Imag_Comp14_Mode18</th>
#       <th>Real_Comp7_Mode37</th>
#       <th>Imag_Comp29_Mode46</th>
#       <th>Imag_Comp21_Mode4</th>
#       <th>Imag_Comp6_Mode49</th>
#       <th>Imag_Comp20_Mode45</th>
#       <th>Real_Comp5_Mode50</th>
#       <th>Real_Comp6_Mode3</th>
#       <th>Imag_Comp17_Mode36</th>
#       <th>Real_Comp8_Mode32</th>
#       <th>Imag_Comp11_Mode27</th>
#       <th>Imag_Comp32_Mode15</th>
#       <th>Real_Comp18_Mode7</th>
#       <th>Imag_Comp20_Mode44</th>
#       <th>Real_Comp11_Mode36</th>
#       <th>Imag_Comp21_Mode28</th>
#       <th>Imag_Comp1_Mode49</th>
#       <th>Real_Comp19_Mode46</th>
#       <th>Real_Comp25_Mode15</th>
#       <th>Imag_Comp3_Mode13</th>
#       <th>Imag_Comp16_Mode39</th>
#       <th>Real_Comp31_Mode14</th>
#       <th>Real_Comp8_Mode36</th>
#       <th>Real_Comp15_Mode34</th>
#       <th>Real_Comp10_Mode48</th>
#       <th>Imag_Comp2_Mode27</th>
#       <th>Imag_Comp10_Mode7</th>
#       <th>Real_Comp23_Mode10</th>
#       <th>Real_Comp30_Mode30</th>
#       <th>Real_Comp19_Mode43</th>
#       <th>Real_Comp12_Mode48</th>
#       <th>Imag_Comp32_Mode29</th>
#       <th>Imag_Comp15_Mode50</th>
#       <th>Imag_Comp22_Mode34</th>
#       <th>Real_Comp1_Mode20</th>
#       <th>Real_Comp11_Mode2</th>
#       <th>Imag_Comp8_Mode47</th>
#       <th>Imag_Comp3_Mode49</th>
#       <th>Real_Comp25_Mode37</th>
#       <th>Imag_Comp12_Mode40</th>
#       <th>Imag_Comp3_Mode21</th>
#       <th>Real_Comp24_Mode47</th>
#       <th>Imag_Comp26_Mode50</th>
#       <th>Imag_Comp9_Mode23</th>
#       <th>Imag_Comp2_Mode28</th>
#       <th>Imag_Comp19_Mode32</th>
#       <th>Real_Comp8_Mode48</th>
#       <th>Imag_Comp31_Mode13</th>
#       <th>Imag_Comp12_Mode50</th>
#       <th>zeta10</th>
#       <th>Imag_Comp9_Mode21</th>
#       <th>Real_Comp15_Mode31</th>
#       <th>Imag_Comp28_Mode24</th>
#       <th>Real_Comp16_Mode22</th>
#       <th>Real_Comp7_Mode1</th>
#       <th>Real_Comp23_Mode33</th>
#       <th>Imag_Comp4_Mode21</th>
#       <th>Imag_Comp17_Mode10</th>
#       <th>Imag_Comp20_Mode41</th>
#       <th>Real_Comp23_Mode28</th>
#       <th>Imag_Comp29_Mode22</th>
#       <th>Real_Comp21_Mode5</th>
#       <th>Imag_Comp19_Mode11</th>
#       <th>Real_Comp22_Mode39</th>
#       <th>Imag_Comp9_Mode41</th>
#       <th>Imag_Comp25_Mode47</th>
#       <th>Imag_Comp13_Mode10</th>
#       <th>Imag_Comp24_Mode27</th>
#       <th>Real_Comp10_Mode46</th>
#       <th>Real_Comp14_Mode46</th>
#       <th>Imag_Comp21_Mode24</th>
#       <th>Real_Comp32_Mode29</th>
#       <th>Real_Comp4_Mode40</th>
#       <th>Imag_Comp13_Mode26</th>
#       <th>Imag_Comp22_Mode44</th>
#       <th>Imag_Comp27_Mode49</th>
#       <th>Imag_Comp9_Mode31</th>
#       <th>Real_Comp26_Mode23</th>
#       <th>Real_Comp14_Mode21</th>
#       <th>Imag_Comp23_Mode37</th>
#       <th>Real_Comp22_Mode8</th>
#       <th>Imag_Comp21_Mode14</th>
#       <th>Imag_Comp10_Mode29</th>
#       <th>Real_Comp15_Mode43</th>
#       <th>Real_Comp8_Mode26</th>
#       <th>Real_Comp2_Mode9</th>
#       <th>Real_Comp1_Mode49</th>
#       <th>Real_Comp17_Mode31</th>

# %%
preds,y,losses = learn.get_preds(with_loss=True)
interp = ClassificationInterpretation(learn, preds, y, losses)

# %%
interp.plot_confusion_matrix(figsize=(10,10))
