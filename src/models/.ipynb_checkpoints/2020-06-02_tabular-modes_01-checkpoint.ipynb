# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.tabular import *

# %%
path=pathlib.Path('/media/tris/tris_files/DEAP_dataset/robots')
path
# Out:
# PosixPath('/media/tris/tris_files/DEAP_dataset/robots')

# %%
df = pd.read_pickle(path/'modes_tabular.pkl').T; df
# Out:
#                        0                      1                    2    \
# 0                 0.054227     0.063823-0.082958i   0.079891-0.061754i
# 1     0.0049932-0.0074566i   -0.0002286-0.034122i  -0.010369+0.015046i
# 2                -0.024087  -0.0019502+0.0041756i   0.098673+0.020781i
# 3      -0.044785+0.042154i     0.018739-0.029055i  -0.03744+0.0097762i
# 4                 -0.33672     -0.094842+0.18482i    0.13909+0.019282i
# ...                    ...                    ...                  ...
# 1275   -0.079096+0.079217i      -0.14581+0.21435i   -0.12332+0.077685i
# 1276               0.10388                0.14071    -0.20823+0.23408i
# 1277    -0.05316+0.046126i     0.043697+0.010904i   -0.07779+0.069944i
# 1278     -0.04111+0.21306i     0.025967+0.091729i   -0.076198-0.21705i
# 1279     -0.02919+0.13204i       0.5169-0.097724i   -0.32303+0.068668i
#
#                       3                     4                     5    \
# 0      -0.11045+0.097761i    -0.09381+0.056034i     0.11209-0.040274i
# 1      0.046595+0.008354i  0.013913+0.00095506i   0.0085045+0.012021i
# 2     0.056515-0.0099204i    -0.11897-0.020148i             -0.019861
# 3     -0.045111+0.045273i   -0.019174-0.063904i    -0.03055-0.058348i
# 4        0.17607-0.21214i     -0.26138-0.02796i    0.27765-0.0091159i
# ...                   ...                   ...                   ...
# 1275    -0.20216+0.21488i       0.28579+0.1522i    0.042002+0.078527i
# 1276   -0.01417-0.046209i      0.32161-0.22926i     0.23003-0.079199i
# 1277  -0.076359+0.023649i     0.080481-0.04164i    0.080517+0.022611i
# 1278   -0.2003+0.0027312i     0.024538+0.15228i  -0.10056+0.00086404i
# 1279     0.14292-0.17701i     0.062804+0.32927i     -0.26527+0.13173i
#
#                        6                      7                     8    \
# 0       0.063025+0.075098i      0.071925+0.10935i   -0.032908+0.034395i
# 1       0.031223+0.027496i    -0.023729+0.047533i  -0.024475-0.0038805i
# 2     -0.0055137-0.028816i    -0.044917+0.091256i   -0.027335+0.042195i
# 3      -0.011689+0.087851i  -0.061873+0.00062156i    0.040421-0.042351i
# 4        -0.14599+0.13403i      -0.14269-0.13397i    0.099949-0.074964i
# ...                    ...                    ...                   ...
# 1275    -0.091812-0.36662i      -0.03133+0.10848i     -0.21586-0.17273i
# 1276     -0.33917-0.03033i      0.046464+0.27947i      0.11793+0.34115i
# 1277      0.31873-0.12721i     -0.04176-0.097664i     -0.033585-0.1017i
# 1278      0.59434+0.11584i     -0.016264-0.12424i     0.17522-0.031038i
# 1279     -0.08682+0.32134i    0.065552-0.0094527i      0.10084+0.21291i
#
#                        9    ...     347     348     349     350     351  \
# 0       -0.11468+0.030763i  ...  8.1931  9.3671  10.309  10.332  11.247
# 1       0.01283-0.0012279i  ...     NaN     NaN     NaN     NaN     NaN
# 2     -0.092782+0.0051776i  ...  9.3753  10.443  11.258  12.283  21.889
# 3       0.047302-0.020101i  ...     NaN     NaN     NaN     NaN     NaN
# 4        0.23569-0.092856i  ...  7.9632  8.1586  8.7132  9.0258  9.9504
# ...                    ...  ...     ...     ...     ...     ...     ...
# 1275    0.023285+0.066423i  ...     NaN     NaN     NaN     NaN     NaN
# 1276      0.31492+0.14441i  ...  8.6994   9.299  9.9535   10.83  11.815
# 1277    0.052554-0.069774i  ...     NaN     NaN     NaN     NaN     NaN
# 1278      -0.1908+0.35375i  ...     NaN     NaN     NaN     NaN     NaN
# 1279     -0.05703-0.03557i  ...     NaN     NaN     NaN     NaN     NaN
#
#          352     353     354     355     356
# 0     11.388  12.406  13.609  21.439  21.921
# 1        NaN     NaN     NaN     NaN     NaN
# 2     25.652  27.164  29.966  39.788  43.919
# 3        NaN     NaN     NaN     NaN     NaN
# 4      11.51  18.343  31.963  41.031  44.012
# ...      ...     ...     ...     ...     ...
# 1275     NaN     NaN     NaN     NaN     NaN
# 1276  12.912  14.489  31.639  40.518  43.954
# 1277     NaN     NaN     NaN     NaN     NaN
# 1278     NaN     NaN     NaN     NaN     NaN
# 1279     NaN     NaN     NaN     NaN     NaN
#
# [1280 rows x 357 columns]

# %%
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

# %%
procs = [FillMissing, Categorify, Normalize]

# %%
data = (TabularList.from_df(df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList, log=True)
                .add_test(TabularList.from_df(test_df, path=path, cat_names=cat_vars, cont_names=cont_vars))
                .databunch())
