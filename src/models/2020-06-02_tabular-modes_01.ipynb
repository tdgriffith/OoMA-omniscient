# %%
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.tabular import *

# %%
path=pathlib.Path('/media/tris/tris_files/DEAP_dataset/robots')
path
# Out:
# PosixPath('/media/tris/tris_files/DEAP_dataset/robots')

# %%
df = pd.read_pickle(path/'modes_tabular.pkl').T; df
# Out:
#                        0                      1                    2    \
# 0                 0.054227     0.063823-0.082958i   0.079891-0.061754i
# 1     0.0049932-0.0074566i   -0.0002286-0.034122i  -0.010369+0.015046i
# 2                -0.024087  -0.0019502+0.0041756i   0.098673+0.020781i
# 3      -0.044785+0.042154i     0.018739-0.029055i  -0.03744+0.0097762i
# 4                 -0.33672     -0.094842+0.18482i    0.13909+0.019282i
# ...                    ...                    ...                  ...
# 1275   -0.079096+0.079217i      -0.14581+0.21435i   -0.12332+0.077685i
# 1276               0.10388                0.14071    -0.20823+0.23408i
# 1277    -0.05316+0.046126i     0.043697+0.010904i   -0.07779+0.069944i
# 1278     -0.04111+0.21306i     0.025967+0.091729i   -0.076198-0.21705i
# 1279     -0.02919+0.13204i       0.5169-0.097724i   -0.32303+0.068668i
#
#                       3                     4                     5    \
# ...

# %%
df=df.rename(columns={357: "dep_var"});df.head()
df=df.rename(columns={0: "test"});df.head()
# Out:
#                    test                      1                    2  \
# 0              0.054227     0.063823-0.082958i   0.079891-0.061754i
# 1  0.0049932-0.0074566i   -0.0002286-0.034122i  -0.010369+0.015046i
# 2             -0.024087  -0.0019502+0.0041756i   0.098673+0.020781i
# 3   -0.044785+0.042154i     0.018739-0.029055i  -0.03744+0.0097762i
# 4              -0.33672     -0.094842+0.18482i    0.13909+0.019282i
#
#                      3                     4                    5  \
# 0   -0.11045+0.097761i    -0.09381+0.056034i    0.11209-0.040274i
# 1   0.046595+0.008354i  0.013913+0.00095506i  0.0085045+0.012021i
# 2  0.056515-0.0099204i    -0.11897-0.020148i            -0.019861
# 3  -0.045111+0.045273i   -0.019174-0.063904i   -0.03055-0.058348i
# 4     0.17607-0.21214i     -0.26138-0.02796i   0.27765-0.0091159i
#
#                       6                      7                     8  \
# 0    0.063025+0.075098i      0.071925+0.10935i   -0.032908+0.034395i
# ...

# %%
# df["dep_var"] = df["dep_var"].astype(str) ;df

# %%
dep_var="dep_var"

# %%
categorify = Categorify(dep_var, 'test')

# %%
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

# %%
valid_idx=pd.DataFrame(test.index.tolist()).to_numpy()

# %%
valid_idx=np.squeeze(valid_idx)

# %%
procs = []

# %%
data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs, cat_names=[])
print(data.train_ds.cont_names)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-d959f49243f1> in <module>
# ----> 1 data = TabularDataBunch.from_df(path, df, dep_var, valid_idx=valid_idx, procs=procs, cat_names=[])
#       2 print(data.train_ds.cont_names)
#
# /media/tris/tris_files/anaconda3/envs/fastai/lib/python3.7/site-packages/fastai/tabular/data.py in from_df(cls, path, df, dep_var, valid_idx, procs, cat_names, cont_names, classes, test_df, bs, val_bs, num_workers, dl_tfms, device, collate_fn, no_check)
#      94         src = (TabularList.from_df(df, path=path, cat_names=cat_names, cont_names=cont_names, procs=procs)
#      95                            .split_by_idx(valid_idx))
# ---> 96         src = src.label_from_df(cols=dep_var) if classes is None else src.label_from_df(cols=dep_var, classes=classes)
# ...
